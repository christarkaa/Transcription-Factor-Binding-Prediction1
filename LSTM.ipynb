# %% [markdown]
# # Transcription Factor Binding Prediction via LSTMs

# %%
# Load libraries
import os
import torch
import torch.nn as nn
import torch.utils.data as du
import joblib
import torch.optim as optim

# %%
# Compute dataset class
class JUND_Dataset(du.Dataset):
    def __init__(self, data_dir):
        super(JUND_Dataset, self).__init__()
        self.X = torch.tensor(joblib.load(f'{data_dir}/shard-0-X.joblib'), dtype=torch.float32)
        self.y = torch.tensor(joblib.load(f'{data_dir}/shard-0-y.joblib'), dtype=torch.float32)
        self.w = torch.tensor(joblib.load(f'{data_dir}/shard-0-w.joblib'), dtype=torch.float32)
        self.a = torch.tensor(joblib.load(f'{data_dir}/shard-0-a.joblib'), dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx], self.w[idx], self.a[idx]

# %%
# Load dataset
train_dataset = JUND_Dataset('/Users/christophertarkaa/Bioinformatics/Machine Learning/TF_data/train_dataset')
valid_dataset = JUND_Dataset('/Users/christophertarkaa/Bioinformatics/Machine Learning/TF_data/valid_dataset')
test_dataset = JUND_Dataset('/Users/christophertarkaa/Bioinformatics/Machine Learning/TF_data/test_dataset')

# %%
# Define LSTM model
class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, layer_dim, output_dim):
        super(LSTMModel, self).__init__()
        self.hidden_dim = hidden_dim
        self.layer_dim = layer_dim

        # LSTM layer
        self.lstm = nn.LSTM(input_dim, hidden_dim, layer_dim, batch_first=True)

        # Fully connected layers
        self.fc1 = nn.Linear(hidden_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim + 1, output_dim)

    def forward(self, x, a):
        # Initialize hidden state with zeros
        h0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim).to(x.device)
        # Initialize cell state with zeros
        c0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim).to(x.device)

        # LSTM forward pass
        out, _ = self.lstm(x, (h0, c0))
        
        # We only want the last output of the sequence
        out = out[:, -1, :]
        
        # Pass the last output through the first fully connected layer
        out = self.fc1(out)
        
        # Concatenate the output with the additional feature 'a'
        out = torch.cat((out, a.view(-1, 1)), dim=1)
        
        # Pass the combined features through the second fully connected layer
        out = self.fc2(out)
        
        return out

# %%
# Hyperparameters
input_size = 4
hidden_size = 128    
lstm_layers = 1      
output_size = 1      
learning_rate = 0.001
batch_size = 20
epochs = 10

# %%
# Initialize model and optimizer
device = torch.device("cpu")  # Set device to CPU (can be changed to 'cuda' for GPU)
model = LSTMModel(input_size, hidden_size, lstm_layers, output_size).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.MSELoss()  # Assuming a regression problem

# %%
# Load training data in batches
train_loader = du.DataLoader(dataset=train_dataset, 
                             batch_size=batch_size, 
                             shuffle=True)

# %%
# Send model to device and set to training mode
model.train()
# Out:
# LSTMModel(
#   (lstm): LSTM(4, 128, batch_first=True)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (fc2): Linear(in_features=129, out_features=1, bias=True)
# )

# %%
# Training loop
for epoch in range(epochs):
    for batch_idx, (data, additional_feature, target, loss_tensor) in enumerate(train_loader):
        data, additional_feature, target = data.to(device), additional_feature.to(device), target.to(device)
        
        optimizer.zero_grad()  # Zero the gradients
        output = model(data, additional_feature)  # Forward pass
        loss = criterion(output, target)  # Calculate loss
        loss.backward()  # Backward pass
        optimizer.step()  # Update weights
        
        if batch_idx % 10 == 0:
            print(f'Epoch [{epoch+1}/{epochs}], Batch [{batch_idx}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/10], Batch [0], Loss: 0.2789
# Epoch [1/10], Batch [10], Loss: 0.0275
# Epoch [1/10], Batch [20], Loss: 0.0067
# Epoch [1/10], Batch [30], Loss: 0.0422
# Epoch [1/10], Batch [40], Loss: 0.1185
# Epoch [1/10], Batch [50], Loss: 0.2996
# Epoch [1/10], Batch [60], Loss: 0.1738
# Epoch [1/10], Batch [70], Loss: 0.1528
# Epoch [1/10], Batch [80], Loss: 0.0229
# Epoch [1/10], Batch [90], Loss: 0.0024
# Epoch [1/10], Batch [100], Loss: 0.0023
# Epoch [1/10], Batch [110], Loss: 0.0010
# Epoch [1/10], Batch [120], Loss: 0.1022
# Epoch [1/10], Batch [130], Loss: 0.0821
# Epoch [1/10], Batch [140], Loss: 0.3605
# Epoch [1/10], Batch [150], Loss: 0.2456
# Epoch [1/10], Batch [160], Loss: 0.3217
# Epoch [1/10], Batch [170], Loss: 1.5837
# Epoch [1/10], Batch [180], Loss: 0.4761
# Epoch [1/10], Batch [190], Loss: 0.0707
# Epoch [1/10], Batch [200], Loss: 0.0361
# Epoch [1/10], Batch [210], Loss: 0.0240
# Epoch [1/10], Batch [220], Loss: 0.0098
# Epoch [1/10], Batch [230], Loss: 0.0117
# Epoch [1/10], Batch [240], Loss: 0.1388
# Epoch [1/10], Batch [250], Loss: 0.3772
# Epoch [1/10], Batch [260], Loss: 0.4074
# Epoch [1/10], Batch [270], Loss: 0.5439
# Epoch [1/10], Batch [280], Loss: 0.2578
# Epoch [1/10], Batch [290], Loss: 0.0644
# Epoch [1/10], Batch [300], Loss: 0.0170
# Epoch [1/10], Batch [310], Loss: 0.0073
# Epoch [1/10], Batch [320], Loss: 0.0299
# Epoch [1/10], Batch [330], Loss: 0.0879
# Epoch [1/10], Batch [340], Loss: 0.0769
# Epoch [1/10], Batch [350], Loss: 0.1650
# Epoch [1/10], Batch [360], Loss: 0.1490
# Epoch [1/10], Batch [370], Loss: 0.0862
# Epoch [1/10], Batch [380], Loss: 0.1163
# Epoch [1/10], Batch [390], Loss: 0.2299
# Epoch [1/10], Batch [400], Loss: 0.1855
# Epoch [1/10], Batch [410], Loss: 0.1905
# Epoch [1/10], Batch [420], Loss: 0.1136
# Epoch [1/10], Batch [430], Loss: 0.0420
# Epoch [1/10], Batch [440], Loss: 0.0585
# Epoch [1/10], Batch [450], Loss: 689.0985
# Epoch [1/10], Batch [460], Loss: 0.2054
# Epoch [1/10], Batch [470], Loss: 0.4833
# Epoch [1/10], Batch [480], Loss: 0.2702
# Epoch [1/10], Batch [490], Loss: 0.0987
# Epoch [1/10], Batch [500], Loss: 0.0342
# Epoch [1/10], Batch [510], Loss: 0.0393
# Epoch [1/10], Batch [520], Loss: 0.0330
# Epoch [1/10], Batch [530], Loss: 0.0209
# Epoch [1/10], Batch [540], Loss: 0.0385
# Epoch [1/10], Batch [550], Loss: 689.2280
# Epoch [1/10], Batch [560], Loss: 687.9985
# Epoch [1/10], Batch [570], Loss: 687.0668
# Epoch [1/10], Batch [580], Loss: 0.2041
# Epoch [1/10], Batch [590], Loss: 0.1406
# Epoch [1/10], Batch [600], Loss: 0.0647
# Epoch [1/10], Batch [610], Loss: 0.0237
# Epoch [1/10], Batch [620], Loss: 0.0793
# Epoch [1/10], Batch [630], Loss: 0.0969
# Epoch [1/10], Batch [640], Loss: 0.0702
# Epoch [1/10], Batch [650], Loss: 0.0300
# Epoch [1/10], Batch [660], Loss: 0.0135
# Epoch [1/10], Batch [670], Loss: 0.0061
# Epoch [1/10], Batch [680], Loss: 0.0423
# Epoch [1/10], Batch [690], Loss: 0.2106
# Epoch [1/10], Batch [700], Loss: 1371.2582
# Epoch [1/10], Batch [710], Loss: 0.4272
# Epoch [1/10], Batch [720], Loss: 0.3933
# Epoch [1/10], Batch [730], Loss: 0.3345
# Epoch [1/10], Batch [740], Loss: 0.2611
# Epoch [1/10], Batch [750], Loss: 0.2584
# Epoch [1/10], Batch [760], Loss: 0.3162
# Epoch [1/10], Batch [770], Loss: 0.2747
# Epoch [1/10], Batch [780], Loss: 0.1132
# Epoch [1/10], Batch [790], Loss: 0.1132
# Epoch [1/10], Batch [800], Loss: 0.1058
# Epoch [1/10], Batch [810], Loss: 0.0996
# Epoch [1/10], Batch [820], Loss: 0.0545
# Epoch [1/10], Batch [830], Loss: 0.0641
# Epoch [1/10], Batch [840], Loss: 0.0570
# Epoch [1/10], Batch [850], Loss: 0.0920
# Epoch [1/10], Batch [860], Loss: 687.4279
# Epoch [1/10], Batch [870], Loss: 0.2159
# Epoch [1/10], Batch [880], Loss: 0.2771
# Epoch [1/10], Batch [890], Loss: 0.4538
# Epoch [1/10], Batch [900], Loss: 0.5740
# Epoch [1/10], Batch [910], Loss: 0.2697
# Epoch [1/10], Batch [920], Loss: 0.2620
# Epoch [1/10], Batch [930], Loss: 0.2079
# Epoch [1/10], Batch [940], Loss: 0.5575
# Epoch [1/10], Batch [950], Loss: 0.6346
# Epoch [1/10], Batch [960], Loss: 0.2495
# Epoch [1/10], Batch [970], Loss: 0.0925
# Epoch [1/10], Batch [980], Loss: 685.1422
# Epoch [1/10], Batch [990], Loss: 0.3723
# Epoch [1/10], Batch [1000], Loss: 0.3027
# Epoch [1/10], Batch [1010], Loss: 1364.8274
# Epoch [1/10], Batch [1020], Loss: 1.0087
# Epoch [1/10], Batch [1030], Loss: 0.9337
# Epoch [1/10], Batch [1040], Loss: 0.3643
# Epoch [1/10], Batch [1050], Loss: 685.0002
# Epoch [1/10], Batch [1060], Loss: 0.1917
# Epoch [1/10], Batch [1070], Loss: 0.2364
# Epoch [1/10], Batch [1080], Loss: 0.2874
# Epoch [1/10], Batch [1090], Loss: 0.4484
# Epoch [1/10], Batch [1100], Loss: 683.9989
# Epoch [1/10], Batch [1110], Loss: 0.4206
# Epoch [1/10], Batch [1120], Loss: 683.8027
# Epoch [1/10], Batch [1130], Loss: 0.3167
# Epoch [1/10], Batch [1140], Loss: 0.3794
# Epoch [1/10], Batch [1150], Loss: 0.3410
# Epoch [1/10], Batch [1160], Loss: 0.4006
# Epoch [1/10], Batch [1170], Loss: 0.3399
# Epoch [1/10], Batch [1180], Loss: 0.3733
# Epoch [1/10], Batch [1190], Loss: 0.4947
# Epoch [1/10], Batch [1200], Loss: 0.4277
# Epoch [1/10], Batch [1210], Loss: 0.3205
# Epoch [1/10], Batch [1220], Loss: 683.1019
# Epoch [1/10], Batch [1230], Loss: 0.4243
# Epoch [1/10], Batch [1240], Loss: 0.3821
# Epoch [1/10], Batch [1250], Loss: 0.1733
# Epoch [1/10], Batch [1260], Loss: 0.0571
# Epoch [1/10], Batch [1270], Loss: 0.0416
# Epoch [1/10], Batch [1280], Loss: 684.9026
# Epoch [1/10], Batch [1290], Loss: 0.2899
# Epoch [1/10], Batch [1300], Loss: 0.2657
# Epoch [1/10], Batch [1310], Loss: 0.2292
# Epoch [1/10], Batch [1320], Loss: 0.2821
# Epoch [1/10], Batch [1330], Loss: 0.2882
# Epoch [1/10], Batch [1340], Loss: 0.1812
# Epoch [1/10], Batch [1350], Loss: 0.1658
# Epoch [1/10], Batch [1360], Loss: 0.1220
# Epoch [1/10], Batch [1370], Loss: 0.0841
# Epoch [1/10], Batch [1380], Loss: 0.1122
# Epoch [1/10], Batch [1390], Loss: 0.1632
# Epoch [1/10], Batch [1400], Loss: 0.1367
# Epoch [1/10], Batch [1410], Loss: 0.1536
# Epoch [1/10], Batch [1420], Loss: 0.1112
# Epoch [1/10], Batch [1430], Loss: 0.0783
# Epoch [1/10], Batch [1440], Loss: 0.0802
# Epoch [1/10], Batch [1450], Loss: 0.0728
# Epoch [1/10], Batch [1460], Loss: 0.0716
# Epoch [1/10], Batch [1470], Loss: 0.0942
# Epoch [1/10], Batch [1480], Loss: 0.1150
# Epoch [1/10], Batch [1490], Loss: 0.1262
# Epoch [1/10], Batch [1500], Loss: 0.1116
# Epoch [1/10], Batch [1510], Loss: 0.1515
# Epoch [1/10], Batch [1520], Loss: 0.1320
# Epoch [1/10], Batch [1530], Loss: 684.5106
# Epoch [1/10], Batch [1540], Loss: 0.1684
# Epoch [1/10], Batch [1550], Loss: 0.1747
# Epoch [1/10], Batch [1560], Loss: 0.1743
# Epoch [1/10], Batch [1570], Loss: 0.1804
# Epoch [1/10], Batch [1580], Loss: 0.1299
# Epoch [1/10], Batch [1590], Loss: 0.1378
# Epoch [1/10], Batch [1600], Loss: 0.2455
# Epoch [1/10], Batch [1610], Loss: 0.1969
# Epoch [1/10], Batch [1620], Loss: 0.1386
# Epoch [1/10], Batch [1630], Loss: 0.1150
# Epoch [1/10], Batch [1640], Loss: 0.1520
# Epoch [1/10], Batch [1650], Loss: 0.2252
# Epoch [1/10], Batch [1660], Loss: 681.7806
# Epoch [1/10], Batch [1670], Loss: 0.3680
# Epoch [1/10], Batch [1680], Loss: 0.5863
# Epoch [1/10], Batch [1690], Loss: 0.6349
# Epoch [1/10], Batch [1700], Loss: 0.5034
# Epoch [1/10], Batch [1710], Loss: 0.4451
# Epoch [1/10], Batch [1720], Loss: 0.2645
# Epoch [1/10], Batch [1730], Loss: 0.1462
# Epoch [1/10], Batch [1740], Loss: 683.6178
# Epoch [1/10], Batch [1750], Loss: 0.1465
# Epoch [1/10], Batch [1760], Loss: 0.1971
# Epoch [1/10], Batch [1770], Loss: 0.2032
# Epoch [1/10], Batch [1780], Loss: 682.9783
# Epoch [1/10], Batch [1790], Loss: 682.7626
# Epoch [1/10], Batch [1800], Loss: 0.1933
# Epoch [1/10], Batch [1810], Loss: 0.3906
# Epoch [1/10], Batch [1820], Loss: 0.4900
# Epoch [1/10], Batch [1830], Loss: 0.5488
# Epoch [1/10], Batch [1840], Loss: 0.9538
# Epoch [1/10], Batch [1850], Loss: 1.2361
# Epoch [1/10], Batch [1860], Loss: 0.5892
# Epoch [1/10], Batch [1870], Loss: 0.6571
# Epoch [1/10], Batch [1880], Loss: 678.9747
# Epoch [1/10], Batch [1890], Loss: 0.6154
# Epoch [1/10], Batch [1900], Loss: 0.4636
# Epoch [1/10], Batch [1910], Loss: 0.3135
# Epoch [1/10], Batch [1920], Loss: 0.2477
# Epoch [1/10], Batch [1930], Loss: 0.1778
# Epoch [1/10], Batch [1940], Loss: 680.5897
# Epoch [1/10], Batch [1950], Loss: 0.5536
# Epoch [1/10], Batch [1960], Loss: 0.6418
# Epoch [1/10], Batch [1970], Loss: 671.1706
# Epoch [1/10], Batch [1980], Loss: 2.4672
# Epoch [1/10], Batch [1990], Loss: 1.5982
# Epoch [1/10], Batch [2000], Loss: 1.1400
# Epoch [1/10], Batch [2010], Loss: 0.6219
# Epoch [1/10], Batch [2020], Loss: 0.3723
# Epoch [1/10], Batch [2030], Loss: 0.2687
# Epoch [1/10], Batch [2040], Loss: 0.1644
# Epoch [1/10], Batch [2050], Loss: 0.1439
# Epoch [1/10], Batch [2060], Loss: 0.0914
# Epoch [1/10], Batch [2070], Loss: 0.0327
# Epoch [1/10], Batch [2080], Loss: 0.0068
# Epoch [1/10], Batch [2090], Loss: 0.0187
# Epoch [1/10], Batch [2100], Loss: 0.0596
# Epoch [1/10], Batch [2110], Loss: 0.0870
# Epoch [1/10], Batch [2120], Loss: 0.1288
# Epoch [1/10], Batch [2130], Loss: 0.1874
# Epoch [1/10], Batch [2140], Loss: 0.1881
# Epoch [1/10], Batch [2150], Loss: 0.2536
# Epoch [1/10], Batch [2160], Loss: 0.1634
# Epoch [1/10], Batch [2170], Loss: 0.2212
# Epoch [1/10], Batch [2180], Loss: 0.2208
# Epoch [1/10], Batch [2190], Loss: 0.1526
# Epoch [1/10], Batch [2200], Loss: 0.1280
# Epoch [1/10], Batch [2210], Loss: 0.1080
# Epoch [1/10], Batch [2220], Loss: 0.0747
# Epoch [1/10], Batch [2230], Loss: 0.0336
# Epoch [1/10], Batch [2240], Loss: 0.0903
# Epoch [1/10], Batch [2250], Loss: 0.0864
# Epoch [1/10], Batch [2260], Loss: 0.1029
# Epoch [1/10], Batch [2270], Loss: 0.1031
# Epoch [1/10], Batch [2280], Loss: 0.0836
# Epoch [1/10], Batch [2290], Loss: 0.1094
# Epoch [1/10], Batch [2300], Loss: 0.0893
# Epoch [1/10], Batch [2310], Loss: 0.1290
# Epoch [1/10], Batch [2320], Loss: 0.1648
# Epoch [1/10], Batch [2330], Loss: 0.1806
# Epoch [1/10], Batch [2340], Loss: 0.1986
# Epoch [1/10], Batch [2350], Loss: 0.1624
# Epoch [1/10], Batch [2360], Loss: 0.1450
# Epoch [1/10], Batch [2370], Loss: 0.2014
# Epoch [1/10], Batch [2380], Loss: 0.1467
# Epoch [1/10], Batch [2390], Loss: 0.1458
# Epoch [1/10], Batch [2400], Loss: 0.1759
# Epoch [1/10], Batch [2410], Loss: 0.1385
# Epoch [1/10], Batch [2420], Loss: 0.1127
# Epoch [1/10], Batch [2430], Loss: 0.1117
# Epoch [1/10], Batch [2440], Loss: 0.1367
# Epoch [1/10], Batch [2450], Loss: 0.1532
# Epoch [1/10], Batch [2460], Loss: 0.1973
# Epoch [1/10], Batch [2470], Loss: 0.2253
# Epoch [1/10], Batch [2480], Loss: 0.3147
# Epoch [1/10], Batch [2490], Loss: 0.3332
# Epoch [1/10], Batch [2500], Loss: 0.2797
# Epoch [1/10], Batch [2510], Loss: 678.9617
# Epoch [1/10], Batch [2520], Loss: 0.2364
# Epoch [1/10], Batch [2530], Loss: 0.2993
# Epoch [1/10], Batch [2540], Loss: 0.3865
# Epoch [1/10], Batch [2550], Loss: 0.4923
# Epoch [1/10], Batch [2560], Loss: 0.4745
# Epoch [1/10], Batch [2570], Loss: 0.4232
# Epoch [1/10], Batch [2580], Loss: 0.3553
# Epoch [1/10], Batch [2590], Loss: 0.2903
# Epoch [1/10], Batch [2600], Loss: 0.3149
# Epoch [1/10], Batch [2610], Loss: 0.2508
# Epoch [1/10], Batch [2620], Loss: 0.1763
# Epoch [1/10], Batch [2630], Loss: 0.1458
# Epoch [1/10], Batch [2640], Loss: 0.1817
# Epoch [1/10], Batch [2650], Loss: 0.2502
# Epoch [1/10], Batch [2660], Loss: 0.3278
# Epoch [1/10], Batch [2670], Loss: 0.2382
# Epoch [1/10], Batch [2680], Loss: 0.2492
# Epoch [1/10], Batch [2690], Loss: 0.2981
# Epoch [1/10], Batch [2700], Loss: 0.3456
# Epoch [1/10], Batch [2710], Loss: 0.2617
# Epoch [1/10], Batch [2720], Loss: 0.1721
# Epoch [1/10], Batch [2730], Loss: 0.1283
# Epoch [1/10], Batch [2740], Loss: 0.1190
# Epoch [1/10], Batch [2750], Loss: 0.1621
# Epoch [1/10], Batch [2760], Loss: 0.1682
# Epoch [1/10], Batch [2770], Loss: 0.1317
# Epoch [1/10], Batch [2780], Loss: 0.1016
# Epoch [1/10], Batch [2790], Loss: 0.1126
# Epoch [1/10], Batch [2800], Loss: 0.0745
# Epoch [1/10], Batch [2810], Loss: 0.0563
# Epoch [1/10], Batch [2820], Loss: 0.1253
# Epoch [1/10], Batch [2830], Loss: 0.1760
# Epoch [1/10], Batch [2840], Loss: 0.2136
# Epoch [1/10], Batch [2850], Loss: 0.1766
# Epoch [1/10], Batch [2860], Loss: 0.2242
# Epoch [1/10], Batch [2870], Loss: 0.2773
# Epoch [1/10], Batch [2880], Loss: 0.2326
# Epoch [1/10], Batch [2890], Loss: 0.2677
# Epoch [1/10], Batch [2900], Loss: 0.2402
# Epoch [1/10], Batch [2910], Loss: 679.2700
# Epoch [1/10], Batch [2920], Loss: 0.1810
# Epoch [1/10], Batch [2930], Loss: 0.2573
# Epoch [1/10], Batch [2940], Loss: 0.2364
# Epoch [1/10], Batch [2950], Loss: 0.3081
# Epoch [1/10], Batch [2960], Loss: 0.3956
# Epoch [1/10], Batch [2970], Loss: 0.3319
# Epoch [1/10], Batch [2980], Loss: 0.2232
# Epoch [1/10], Batch [2990], Loss: 0.1568
# Epoch [1/10], Batch [3000], Loss: 680.5551
# Epoch [1/10], Batch [3010], Loss: 678.1531
# Epoch [1/10], Batch [3020], Loss: 0.3078
# Epoch [1/10], Batch [3030], Loss: 0.4813
# Epoch [1/10], Batch [3040], Loss: 0.7325
# Epoch [1/10], Batch [3050], Loss: 0.8340
# Epoch [1/10], Batch [3060], Loss: 0.7242
# Epoch [1/10], Batch [3070], Loss: 0.5903
# Epoch [1/10], Batch [3080], Loss: 0.4991
# Epoch [1/10], Batch [3090], Loss: 0.3403
# Epoch [1/10], Batch [3100], Loss: 0.2308
# Epoch [1/10], Batch [3110], Loss: 0.1799
# Epoch [1/10], Batch [3120], Loss: 0.1474
# Epoch [1/10], Batch [3130], Loss: 0.1306
# Epoch [1/10], Batch [3140], Loss: 679.2681
# Epoch [1/10], Batch [3150], Loss: 0.1774
# Epoch [1/10], Batch [3160], Loss: 0.2784
# Epoch [1/10], Batch [3170], Loss: 0.3142
# Epoch [1/10], Batch [3180], Loss: 0.2279
# Epoch [1/10], Batch [3190], Loss: 0.1460
# Epoch [1/10], Batch [3200], Loss: 0.1184
# Epoch [1/10], Batch [3210], Loss: 0.1618
# Epoch [1/10], Batch [3220], Loss: 0.1507
# Epoch [1/10], Batch [3230], Loss: 0.0986
# Epoch [1/10], Batch [3240], Loss: 0.0860
# Epoch [1/10], Batch [3250], Loss: 679.4601
# Epoch [1/10], Batch [3260], Loss: 0.1443
# Epoch [1/10], Batch [3270], Loss: 0.1742
# Epoch [1/10], Batch [3280], Loss: 0.1841
# Epoch [1/10], Batch [3290], Loss: 0.1215
# Epoch [1/10], Batch [3300], Loss: 0.1109
# Epoch [1/10], Batch [3310], Loss: 0.1602
# Epoch [1/10], Batch [3320], Loss: 0.1664
# Epoch [1/10], Batch [3330], Loss: 0.1603
# Epoch [1/10], Batch [3340], Loss: 0.2176
# Epoch [1/10], Batch [3350], Loss: 678.2269
# Epoch [1/10], Batch [3360], Loss: 677.6762
# Epoch [1/10], Batch [3370], Loss: 0.2725
# Epoch [1/10], Batch [3380], Loss: 676.2674
# Epoch [1/10], Batch [3390], Loss: 0.3644
# Epoch [1/10], Batch [3400], Loss: 0.3337
# Epoch [1/10], Batch [3410], Loss: 0.3037
# Epoch [1/10], Batch [3420], Loss: 0.2344
# Epoch [1/10], Batch [3430], Loss: 0.2078
# Epoch [1/10], Batch [3440], Loss: 0.2375
# Epoch [1/10], Batch [3450], Loss: 0.2314
# Epoch [1/10], Batch [3460], Loss: 0.2345
# Epoch [1/10], Batch [3470], Loss: 0.1979
# Epoch [1/10], Batch [3480], Loss: 0.1444
# Epoch [1/10], Batch [3490], Loss: 0.1040
# Epoch [1/10], Batch [3500], Loss: 0.1234
# Epoch [1/10], Batch [3510], Loss: 0.1733
# Epoch [1/10], Batch [3520], Loss: 0.1633
# Epoch [1/10], Batch [3530], Loss: 0.1612
# Epoch [1/10], Batch [3540], Loss: 0.2223
# Epoch [1/10], Batch [3550], Loss: 0.2021
# Epoch [1/10], Batch [3560], Loss: 0.1981
# Epoch [1/10], Batch [3570], Loss: 0.1921
# Epoch [1/10], Batch [3580], Loss: 0.2344
# Epoch [1/10], Batch [3590], Loss: 0.2428
# Epoch [1/10], Batch [3600], Loss: 0.2793
# Epoch [1/10], Batch [3610], Loss: 0.4065
# Epoch [1/10], Batch [3620], Loss: 0.5245
# Epoch [1/10], Batch [3630], Loss: 0.5277
# Epoch [1/10], Batch [3640], Loss: 0.5128
# Epoch [1/10], Batch [3650], Loss: 0.4816
# Epoch [1/10], Batch [3660], Loss: 0.3552
# Epoch [1/10], Batch [3670], Loss: 0.2353
# Epoch [1/10], Batch [3680], Loss: 0.1598
# Epoch [1/10], Batch [3690], Loss: 0.1246
# Epoch [1/10], Batch [3700], Loss: 0.1070
# Epoch [1/10], Batch [3710], Loss: 0.0885
# Epoch [1/10], Batch [3720], Loss: 0.0635
# Epoch [1/10], Batch [3730], Loss: 0.0667
# Epoch [1/10], Batch [3740], Loss: 0.0598
# Epoch [1/10], Batch [3750], Loss: 0.0948
# Epoch [1/10], Batch [3760], Loss: 0.1088
# Epoch [1/10], Batch [3770], Loss: 0.1046
# Epoch [1/10], Batch [3780], Loss: 0.1389
# Epoch [1/10], Batch [3790], Loss: 0.1671
# Epoch [1/10], Batch [3800], Loss: 0.1397
# Epoch [1/10], Batch [3810], Loss: 0.1453
# Epoch [1/10], Batch [3820], Loss: 0.1415
# Epoch [1/10], Batch [3830], Loss: 676.3346
# Epoch [1/10], Batch [3840], Loss: 0.3534
# Epoch [1/10], Batch [3850], Loss: 0.4312
# Epoch [1/10], Batch [3860], Loss: 0.3700
# Epoch [1/10], Batch [3870], Loss: 0.3753
# Epoch [1/10], Batch [3880], Loss: 0.4659
# Epoch [1/10], Batch [3890], Loss: 0.5325
# Epoch [1/10], Batch [3900], Loss: 0.6645
# Epoch [1/10], Batch [3910], Loss: 0.6390
# Epoch [1/10], Batch [3920], Loss: 0.5406
# Epoch [1/10], Batch [3930], Loss: 0.5095
# Epoch [1/10], Batch [3940], Loss: 0.5394
# Epoch [1/10], Batch [3950], Loss: 0.4964
# Epoch [1/10], Batch [3960], Loss: 0.4567
# Epoch [1/10], Batch [3970], Loss: 0.4751
# Epoch [1/10], Batch [3980], Loss: 0.4153
# Epoch [1/10], Batch [3990], Loss: 0.3623
# Epoch [1/10], Batch [4000], Loss: 0.3715
# Epoch [1/10], Batch [4010], Loss: 0.3080
# Epoch [1/10], Batch [4020], Loss: 0.2189
# Epoch [1/10], Batch [4030], Loss: 0.1638
# Epoch [1/10], Batch [4040], Loss: 0.2997
# Epoch [1/10], Batch [4050], Loss: 0.3794
# Epoch [1/10], Batch [4060], Loss: 0.3450
# Epoch [1/10], Batch [4070], Loss: 0.2484
# Epoch [1/10], Batch [4080], Loss: 672.5789
# Epoch [1/10], Batch [4090], Loss: 0.5721
# Epoch [1/10], Batch [4100], Loss: 0.5754
# Epoch [1/10], Batch [4110], Loss: 0.5187
# Epoch [1/10], Batch [4120], Loss: 0.3721
# Epoch [1/10], Batch [4130], Loss: 0.2377
# Epoch [1/10], Batch [4140], Loss: 0.1870
# Epoch [1/10], Batch [4150], Loss: 0.1454
# Epoch [1/10], Batch [4160], Loss: 0.0998
# Epoch [1/10], Batch [4170], Loss: 0.1632
# Epoch [1/10], Batch [4180], Loss: 0.1699
# Epoch [1/10], Batch [4190], Loss: 0.1505
# Epoch [1/10], Batch [4200], Loss: 674.4109
# Epoch [1/10], Batch [4210], Loss: 0.1514
# Epoch [1/10], Batch [4220], Loss: 0.1584
# Epoch [1/10], Batch [4230], Loss: 0.1503
# Epoch [1/10], Batch [4240], Loss: 0.1640
# Epoch [1/10], Batch [4250], Loss: 0.1804
# Epoch [1/10], Batch [4260], Loss: 0.2271
# Epoch [1/10], Batch [4270], Loss: 0.3713
# Epoch [1/10], Batch [4280], Loss: 0.3929
# Epoch [1/10], Batch [4290], Loss: 0.3757
# Epoch [1/10], Batch [4300], Loss: 0.3726
# Epoch [1/10], Batch [4310], Loss: 0.3181
# Epoch [1/10], Batch [4320], Loss: 0.4133
# Epoch [1/10], Batch [4330], Loss: 0.7169
# Epoch [1/10], Batch [4340], Loss: 0.7810
# Epoch [1/10], Batch [4350], Loss: 0.6614
# Epoch [1/10], Batch [4360], Loss: 0.5756
# Epoch [1/10], Batch [4370], Loss: 0.4385
# Epoch [1/10], Batch [4380], Loss: 0.2907
# Epoch [1/10], Batch [4390], Loss: 0.2673
# Epoch [1/10], Batch [4400], Loss: 0.2442
# Epoch [1/10], Batch [4410], Loss: 0.2271
# Epoch [1/10], Batch [4420], Loss: 0.2506
# Epoch [1/10], Batch [4430], Loss: 0.2297
# Epoch [1/10], Batch [4440], Loss: 0.1934
# Epoch [1/10], Batch [4450], Loss: 0.2621
# Epoch [1/10], Batch [4460], Loss: 0.3124
# Epoch [1/10], Batch [4470], Loss: 0.3992
# Epoch [1/10], Batch [4480], Loss: 0.4843
# Epoch [1/10], Batch [4490], Loss: 0.3549
# Epoch [1/10], Batch [4500], Loss: 0.2523
# Epoch [1/10], Batch [4510], Loss: 0.1872
# Epoch [1/10], Batch [4520], Loss: 0.1585
# Epoch [1/10], Batch [4530], Loss: 0.1343
# Epoch [1/10], Batch [4540], Loss: 675.1144
# Epoch [1/10], Batch [4550], Loss: 0.0996
# Epoch [1/10], Batch [4560], Loss: 0.0789
# Epoch [1/10], Batch [4570], Loss: 0.0554
# Epoch [1/10], Batch [4580], Loss: 0.0772
# Epoch [1/10], Batch [4590], Loss: 0.1140
# Epoch [1/10], Batch [4600], Loss: 0.1549
# Epoch [1/10], Batch [4610], Loss: 0.1437
# Epoch [1/10], Batch [4620], Loss: 0.1581
# Epoch [1/10], Batch [4630], Loss: 0.1728
# Epoch [1/10], Batch [4640], Loss: 0.1726
# Epoch [1/10], Batch [4650], Loss: 0.1529
# Epoch [1/10], Batch [4660], Loss: 0.1735
# Epoch [1/10], Batch [4670], Loss: 0.1505
# Epoch [1/10], Batch [4680], Loss: 0.1248
# Epoch [1/10], Batch [4690], Loss: 0.0827
# Epoch [1/10], Batch [4700], Loss: 674.8593
# Epoch [1/10], Batch [4710], Loss: 0.0885
# Epoch [1/10], Batch [4720], Loss: 0.0939
# Epoch [1/10], Batch [4730], Loss: 0.2079
# Epoch [1/10], Batch [4740], Loss: 0.4200
# Epoch [1/10], Batch [4750], Loss: 0.8946
# Epoch [1/10], Batch [4760], Loss: 0.6747
# Epoch [1/10], Batch [4770], Loss: 0.5496
# Epoch [1/10], Batch [4780], Loss: 0.7140
# Epoch [1/10], Batch [4790], Loss: 0.7606
# Epoch [1/10], Batch [4800], Loss: 0.8392
# Epoch [1/10], Batch [4810], Loss: 0.4914
# Epoch [1/10], Batch [4820], Loss: 0.3079
# Epoch [1/10], Batch [4830], Loss: 0.1871
# Epoch [1/10], Batch [4840], Loss: 0.1033
# Epoch [1/10], Batch [4850], Loss: 0.1102
# Epoch [1/10], Batch [4860], Loss: 0.1372
# Epoch [1/10], Batch [4870], Loss: 0.1339
# Epoch [1/10], Batch [4880], Loss: 0.1811
# Epoch [1/10], Batch [4890], Loss: 0.2604
# Epoch [1/10], Batch [4900], Loss: 0.3674
# Epoch [1/10], Batch [4910], Loss: 669.1534
# Epoch [1/10], Batch [4920], Loss: 0.7984
# Epoch [1/10], Batch [4930], Loss: 0.9243
# Epoch [1/10], Batch [4940], Loss: 0.8912
# Epoch [1/10], Batch [4950], Loss: 0.5990
# Epoch [1/10], Batch [4960], Loss: 0.3764
# Epoch [1/10], Batch [4970], Loss: 0.3044
# Epoch [1/10], Batch [4980], Loss: 0.2301
# Epoch [1/10], Batch [4990], Loss: 0.1788
# Epoch [1/10], Batch [5000], Loss: 0.1243
# Epoch [1/10], Batch [5010], Loss: 0.0902
# Epoch [1/10], Batch [5020], Loss: 0.0553
# Epoch [1/10], Batch [5030], Loss: 0.0362
# Epoch [1/10], Batch [5040], Loss: 0.0554
# Epoch [1/10], Batch [5050], Loss: 0.0757
# Epoch [1/10], Batch [5060], Loss: 0.0706
# Epoch [1/10], Batch [5070], Loss: 0.0530
# Epoch [1/10], Batch [5080], Loss: 673.8718
# Epoch [1/10], Batch [5090], Loss: 0.0567
# Epoch [1/10], Batch [5100], Loss: 0.0475
# Epoch [1/10], Batch [5110], Loss: 0.0374
# Epoch [1/10], Batch [5120], Loss: 673.7709
# Epoch [1/10], Batch [5130], Loss: 0.0631
# Epoch [1/10], Batch [5140], Loss: 0.0619
# Epoch [1/10], Batch [5150], Loss: 0.0572
# Epoch [1/10], Batch [5160], Loss: 0.0774
# Epoch [1/10], Batch [5170], Loss: 0.0911
# Epoch [1/10], Batch [5180], Loss: 0.0852
# Epoch [1/10], Batch [5190], Loss: 0.0707
# Epoch [1/10], Batch [5200], Loss: 0.0541
# Epoch [1/10], Batch [5210], Loss: 0.0969
# Epoch [1/10], Batch [5220], Loss: 672.4341
# Epoch [1/10], Batch [5230], Loss: 0.1455
# Epoch [1/10], Batch [5240], Loss: 0.1559
# Epoch [1/10], Batch [5250], Loss: 672.0991
# Epoch [1/10], Batch [5260], Loss: 0.1410
# Epoch [1/10], Batch [5270], Loss: 0.1253
# Epoch [1/10], Batch [5280], Loss: 0.1020
# Epoch [1/10], Batch [5290], Loss: 0.0735
# Epoch [1/10], Batch [5300], Loss: 672.8713
# Epoch [1/10], Batch [5310], Loss: 0.0648
# Epoch [1/10], Batch [5320], Loss: 0.0593
# Epoch [1/10], Batch [5330], Loss: 0.0552
# Epoch [1/10], Batch [5340], Loss: 0.0590
# Epoch [1/10], Batch [5350], Loss: 0.0532
# Epoch [1/10], Batch [5360], Loss: 0.0493
# Epoch [1/10], Batch [5370], Loss: 0.0552
# Epoch [1/10], Batch [5380], Loss: 0.0464
# Epoch [1/10], Batch [5390], Loss: 0.0677
# Epoch [1/10], Batch [5400], Loss: 0.1159
# Epoch [1/10], Batch [5410], Loss: 0.1330
# Epoch [1/10], Batch [5420], Loss: 0.1815
# Epoch [1/10], Batch [5430], Loss: 0.2831
# Epoch [1/10], Batch [5440], Loss: 0.3056
# Epoch [1/10], Batch [5450], Loss: 0.2724
# Epoch [1/10], Batch [5460], Loss: 0.2081
# Epoch [1/10], Batch [5470], Loss: 0.1334
# Epoch [1/10], Batch [5480], Loss: 0.1070
# Epoch [1/10], Batch [5490], Loss: 0.0881
# Epoch [1/10], Batch [5500], Loss: 0.1294
# Epoch [1/10], Batch [5510], Loss: 0.1422
# Epoch [1/10], Batch [5520], Loss: 0.1562
# Epoch [1/10], Batch [5530], Loss: 0.1455
# Epoch [1/10], Batch [5540], Loss: 0.1170
# Epoch [1/10], Batch [5550], Loss: 0.0881
# Epoch [1/10], Batch [5560], Loss: 0.0763
# Epoch [1/10], Batch [5570], Loss: 0.0976
# Epoch [1/10], Batch [5580], Loss: 0.1322
# Epoch [1/10], Batch [5590], Loss: 0.1969
# Epoch [1/10], Batch [5600], Loss: 0.1865
# Epoch [1/10], Batch [5610], Loss: 669.8646
# Epoch [1/10], Batch [5620], Loss: 0.3215
# Epoch [1/10], Batch [5630], Loss: 0.3088
# Epoch [1/10], Batch [5640], Loss: 0.2704
# Epoch [1/10], Batch [5650], Loss: 0.2715
# Epoch [1/10], Batch [5660], Loss: 0.2882
# Epoch [1/10], Batch [5670], Loss: 0.3230
# Epoch [1/10], Batch [5680], Loss: 0.2881
# Epoch [1/10], Batch [5690], Loss: 0.3835
# Epoch [1/10], Batch [5700], Loss: 0.4153
# Epoch [1/10], Batch [5710], Loss: 0.4076
# Epoch [1/10], Batch [5720], Loss: 0.3499
# Epoch [1/10], Batch [5730], Loss: 0.3472
# Epoch [1/10], Batch [5740], Loss: 0.2878
# Epoch [1/10], Batch [5750], Loss: 0.2475
# Epoch [1/10], Batch [5760], Loss: 0.2962
# Epoch [1/10], Batch [5770], Loss: 0.3451
# Epoch [1/10], Batch [5780], Loss: 0.3594
# Epoch [1/10], Batch [5790], Loss: 667.1519
# Epoch [1/10], Batch [5800], Loss: 0.4825
# Epoch [1/10], Batch [5810], Loss: 0.4497
# Epoch [1/10], Batch [5820], Loss: 0.3800
# Epoch [1/10], Batch [5830], Loss: 0.2863
# Epoch [1/10], Batch [5840], Loss: 0.2108
# Epoch [1/10], Batch [5850], Loss: 0.1542
# Epoch [1/10], Batch [5860], Loss: 0.1600
# Epoch [1/10], Batch [5870], Loss: 0.2079
# Epoch [1/10], Batch [5880], Loss: 0.1816
# Epoch [1/10], Batch [5890], Loss: 0.1720
# Epoch [1/10], Batch [5900], Loss: 0.1595
# Epoch [1/10], Batch [5910], Loss: 669.0880
# Epoch [1/10], Batch [5920], Loss: 0.1751
# Epoch [1/10], Batch [5930], Loss: 669.4235
# Epoch [1/10], Batch [5940], Loss: 0.1829
# Epoch [1/10], Batch [5950], Loss: 0.2020
# Epoch [1/10], Batch [5960], Loss: 0.2215
# Epoch [1/10], Batch [5970], Loss: 0.2139
# Epoch [1/10], Batch [5980], Loss: 0.1640
# Epoch [1/10], Batch [5990], Loss: 0.1559
# Epoch [1/10], Batch [6000], Loss: 0.1510
# Epoch [1/10], Batch [6010], Loss: 0.1566
# Epoch [1/10], Batch [6020], Loss: 0.1599
# Epoch [1/10], Batch [6030], Loss: 0.1336
# Epoch [1/10], Batch [6040], Loss: 669.1486
# Epoch [1/10], Batch [6050], Loss: 0.1893
# Epoch [1/10], Batch [6060], Loss: 0.1848
# Epoch [1/10], Batch [6070], Loss: 0.1793
# Epoch [1/10], Batch [6080], Loss: 0.1792
# Epoch [1/10], Batch [6090], Loss: 0.1754
# Epoch [1/10], Batch [6100], Loss: 0.1614
# Epoch [1/10], Batch [6110], Loss: 0.1524
# Epoch [1/10], Batch [6120], Loss: 0.1301
# Epoch [1/10], Batch [6130], Loss: 0.1037
# Epoch [1/10], Batch [6140], Loss: 0.0885
# Epoch [1/10], Batch [6150], Loss: 0.1135
# Epoch [1/10], Batch [6160], Loss: 0.1280
# Epoch [1/10], Batch [6170], Loss: 0.1276
# Epoch [1/10], Batch [6180], Loss: 0.1028
# Epoch [1/10], Batch [6190], Loss: 0.0948
# Epoch [1/10], Batch [6200], Loss: 0.1019
# Epoch [1/10], Batch [6210], Loss: 0.1078
# Epoch [1/10], Batch [6220], Loss: 0.1253
# Epoch [1/10], Batch [6230], Loss: 0.1336
# Epoch [1/10], Batch [6240], Loss: 0.1189
# Epoch [1/10], Batch [6250], Loss: 0.1133
# Epoch [1/10], Batch [6260], Loss: 0.1009
# Epoch [1/10], Batch [6270], Loss: 0.1117
# Epoch [1/10], Batch [6280], Loss: 0.0996
# Epoch [1/10], Batch [6290], Loss: 0.0853
# Epoch [1/10], Batch [6300], Loss: 0.0620
# Epoch [1/10], Batch [6310], Loss: 1341.5840
# Epoch [1/10], Batch [6320], Loss: 0.1050
# Epoch [1/10], Batch [6330], Loss: 0.1294
# Epoch [1/10], Batch [6340], Loss: 0.1326
# Epoch [1/10], Batch [6350], Loss: 0.1092
# Epoch [1/10], Batch [6360], Loss: 0.1049
# Epoch [1/10], Batch [6370], Loss: 669.3613
# Epoch [1/10], Batch [6380], Loss: 0.1271
# Epoch [1/10], Batch [6390], Loss: 0.2028
# Epoch [1/10], Batch [6400], Loss: 0.2907
# Epoch [1/10], Batch [6410], Loss: 0.2662
# Epoch [1/10], Batch [6420], Loss: 0.2125
# Epoch [1/10], Batch [6430], Loss: 0.1869
# Epoch [1/10], Batch [6440], Loss: 667.8879
# Epoch [1/10], Batch [6450], Loss: 0.2403
# Epoch [1/10], Batch [6460], Loss: 0.3116
# Epoch [1/10], Batch [6470], Loss: 0.3870
# Epoch [1/10], Batch [6480], Loss: 0.3453
# Epoch [1/10], Batch [6490], Loss: 0.2766
# Epoch [1/10], Batch [6500], Loss: 0.2455
# Epoch [1/10], Batch [6510], Loss: 0.2253
# Epoch [1/10], Batch [6520], Loss: 0.1969
# Epoch [1/10], Batch [6530], Loss: 0.1563
# Epoch [1/10], Batch [6540], Loss: 0.1471
# Epoch [1/10], Batch [6550], Loss: 0.1631
# Epoch [1/10], Batch [6560], Loss: 0.1436
# Epoch [1/10], Batch [6570], Loss: 0.1764
# Epoch [1/10], Batch [6580], Loss: 0.1735
# Epoch [1/10], Batch [6590], Loss: 0.1414
# Epoch [1/10], Batch [6600], Loss: 0.1144
# Epoch [1/10], Batch [6610], Loss: 0.0848
# Epoch [1/10], Batch [6620], Loss: 0.0731
# Epoch [1/10], Batch [6630], Loss: 0.0977
# Epoch [1/10], Batch [6640], Loss: 0.0985
# Epoch [1/10], Batch [6650], Loss: 0.0831
# Epoch [1/10], Batch [6660], Loss: 0.0816
# Epoch [1/10], Batch [6670], Loss: 0.0832
# Epoch [1/10], Batch [6680], Loss: 668.3159
# Epoch [1/10], Batch [6690], Loss: 0.1062
# Epoch [1/10], Batch [6700], Loss: 0.1181
# Epoch [1/10], Batch [6710], Loss: 0.1118
# Epoch [1/10], Batch [6720], Loss: 0.1306
# Epoch [1/10], Batch [6730], Loss: 666.9420
# Epoch [1/10], Batch [6740], Loss: 0.2495
# Epoch [1/10], Batch [6750], Loss: 0.2618
# Epoch [1/10], Batch [6760], Loss: 665.6874
# Epoch [1/10], Batch [6770], Loss: 0.3240
# Epoch [1/10], Batch [6780], Loss: 0.2580
# Epoch [1/10], Batch [6790], Loss: 0.2273
# Epoch [1/10], Batch [6800], Loss: 0.1829
# Epoch [1/10], Batch [6810], Loss: 0.1441
# Epoch [1/10], Batch [6820], Loss: 0.1090
# Epoch [1/10], Batch [6830], Loss: 0.0718
# Epoch [1/10], Batch [6840], Loss: 667.6934
# Epoch [1/10], Batch [6850], Loss: 0.1048
# Epoch [1/10], Batch [6860], Loss: 668.1185
# Epoch [1/10], Batch [6870], Loss: 0.0964
# Epoch [1/10], Batch [6880], Loss: 0.0845
# Epoch [1/10], Batch [6890], Loss: 0.0666
# Epoch [1/10], Batch [6900], Loss: 0.0770
# Epoch [1/10], Batch [6910], Loss: 0.0676
# Epoch [1/10], Batch [6920], Loss: 0.0760
# Epoch [1/10], Batch [6930], Loss: 0.1284
# Epoch [1/10], Batch [6940], Loss: 0.1421
# Epoch [1/10], Batch [6950], Loss: 0.1506
# Epoch [1/10], Batch [6960], Loss: 0.1968
# Epoch [1/10], Batch [6970], Loss: 0.2099
# Epoch [1/10], Batch [6980], Loss: 0.2046
# Epoch [1/10], Batch [6990], Loss: 0.2006
# Epoch [1/10], Batch [7000], Loss: 0.2189
# Epoch [1/10], Batch [7010], Loss: 0.2078
# Epoch [1/10], Batch [7020], Loss: 0.2367
# Epoch [1/10], Batch [7030], Loss: 664.9586
# Epoch [1/10], Batch [7040], Loss: 0.3460
# Epoch [1/10], Batch [7050], Loss: 0.4180
# Epoch [1/10], Batch [7060], Loss: 0.3704
# Epoch [1/10], Batch [7070], Loss: 0.2854
# Epoch [1/10], Batch [7080], Loss: 0.2619
# Epoch [1/10], Batch [7090], Loss: 0.2118
# Epoch [1/10], Batch [7100], Loss: 0.2001
# Epoch [1/10], Batch [7110], Loss: 0.2001
# Epoch [1/10], Batch [7120], Loss: 0.2162
# Epoch [1/10], Batch [7130], Loss: 0.2123
# Epoch [1/10], Batch [7140], Loss: 1330.5740
# Epoch [1/10], Batch [7150], Loss: 664.6295
# Epoch [1/10], Batch [7160], Loss: 0.3275
# Epoch [1/10], Batch [7170], Loss: 0.2900
# Epoch [1/10], Batch [7180], Loss: 0.2673
# Epoch [1/10], Batch [7190], Loss: 0.2650
# Epoch [1/10], Batch [7200], Loss: 0.3337
# Epoch [1/10], Batch [7210], Loss: 0.2987
# Epoch [1/10], Batch [7220], Loss: 0.2865
# Epoch [1/10], Batch [7230], Loss: 0.2897
# Epoch [1/10], Batch [7240], Loss: 0.2681
# Epoch [1/10], Batch [7250], Loss: 0.2407
# Epoch [1/10], Batch [7260], Loss: 0.1905
# Epoch [1/10], Batch [7270], Loss: 664.6942
# Epoch [1/10], Batch [7280], Loss: 0.3111
# Epoch [1/10], Batch [7290], Loss: 0.3257
# Epoch [1/10], Batch [7300], Loss: 0.3313
# Epoch [1/10], Batch [7310], Loss: 0.3144
# Epoch [1/10], Batch [7320], Loss: 0.2789
# Epoch [1/10], Batch [7330], Loss: 0.2158
# Epoch [1/10], Batch [7340], Loss: 0.2436
# Epoch [1/10], Batch [7350], Loss: 0.2302
# Epoch [1/10], Batch [7360], Loss: 0.1741
# Epoch [1/10], Batch [7370], Loss: 0.1721
# Epoch [1/10], Batch [7380], Loss: 665.0804
# Epoch [1/10], Batch [7390], Loss: 0.2130
# Epoch [1/10], Batch [7400], Loss: 0.2808
# Epoch [1/10], Batch [7410], Loss: 0.3388
# Epoch [1/10], Batch [7420], Loss: 0.3104
# Epoch [1/10], Batch [7430], Loss: 663.0981
# Epoch [1/10], Batch [7440], Loss: 0.2561
# Epoch [1/10], Batch [7450], Loss: 0.2352
# Epoch [1/10], Batch [7460], Loss: 0.2721
# Epoch [1/10], Batch [7470], Loss: 0.2209
# Epoch [1/10], Batch [7480], Loss: 0.1598
# Epoch [1/10], Batch [7490], Loss: 0.1484
# Epoch [1/10], Batch [7500], Loss: 664.9818
# Epoch [1/10], Batch [7510], Loss: 0.1329
# Epoch [1/10], Batch [7520], Loss: 0.1688
# Epoch [1/10], Batch [7530], Loss: 664.6777
# Epoch [1/10], Batch [7540], Loss: 0.2246
# Epoch [1/10], Batch [7550], Loss: 0.2303
# Epoch [1/10], Batch [7560], Loss: 663.6432
# Epoch [1/10], Batch [7570], Loss: 0.2283
# Epoch [1/10], Batch [7580], Loss: 0.2330
# Epoch [1/10], Batch [7590], Loss: 663.1486
# Epoch [1/10], Batch [7600], Loss: 0.2559
# Epoch [1/10], Batch [7610], Loss: 0.2759
# Epoch [1/10], Batch [7620], Loss: 0.2743
# Epoch [1/10], Batch [7630], Loss: 0.2765
# Epoch [1/10], Batch [7640], Loss: 0.2590
# Epoch [1/10], Batch [7650], Loss: 0.2403
# Epoch [1/10], Batch [7660], Loss: 0.2726
# Epoch [1/10], Batch [7670], Loss: 0.3013
# Epoch [1/10], Batch [7680], Loss: 0.3369
# Epoch [1/10], Batch [7690], Loss: 0.3794
# Epoch [1/10], Batch [7700], Loss: 0.4072
# Epoch [1/10], Batch [7710], Loss: 0.4459
# Epoch [1/10], Batch [7720], Loss: 0.4840
# Epoch [1/10], Batch [7730], Loss: 0.4790
# Epoch [1/10], Batch [7740], Loss: 0.4981
# Epoch [1/10], Batch [7750], Loss: 660.3035
# Epoch [1/10], Batch [7760], Loss: 0.4904
# Epoch [1/10], Batch [7770], Loss: 0.4425
# Epoch [1/10], Batch [7780], Loss: 0.4036
# Epoch [1/10], Batch [7790], Loss: 0.5563
# Epoch [1/10], Batch [7800], Loss: 0.6105
# Epoch [1/10], Batch [7810], Loss: 658.8651
# Epoch [1/10], Batch [7820], Loss: 0.7708
# Epoch [1/10], Batch [7830], Loss: 0.6714
# Epoch [1/10], Batch [7840], Loss: 0.5657
# Epoch [1/10], Batch [7850], Loss: 0.4291
# Epoch [1/10], Batch [7860], Loss: 0.3058
# Epoch [1/10], Batch [7870], Loss: 0.2448
# Epoch [1/10], Batch [7880], Loss: 662.4220
# Epoch [1/10], Batch [7890], Loss: 0.2681
# Epoch [1/10], Batch [7900], Loss: 0.2297
# Epoch [1/10], Batch [7910], Loss: 663.0808
# Epoch [1/10], Batch [7920], Loss: 662.0886
# Epoch [1/10], Batch [7930], Loss: 0.2456
# Epoch [1/10], Batch [7940], Loss: 0.2587
# Epoch [1/10], Batch [7950], Loss: 0.3377
# Epoch [1/10], Batch [7960], Loss: 0.3404
# Epoch [1/10], Batch [7970], Loss: 0.3035
# Epoch [1/10], Batch [7980], Loss: 0.2380
# Epoch [1/10], Batch [7990], Loss: 0.1911
# Epoch [1/10], Batch [8000], Loss: 0.1809
# Epoch [1/10], Batch [8010], Loss: 0.1916
# Epoch [1/10], Batch [8020], Loss: 0.2100
# Epoch [1/10], Batch [8030], Loss: 0.1798
# Epoch [1/10], Batch [8040], Loss: 0.1723
# Epoch [1/10], Batch [8050], Loss: 0.2139
# Epoch [1/10], Batch [8060], Loss: 0.2133
# Epoch [1/10], Batch [8070], Loss: 0.2129
# Epoch [1/10], Batch [8080], Loss: 0.2043
# Epoch [1/10], Batch [8090], Loss: 662.5588
# Epoch [1/10], Batch [8100], Loss: 0.2790
# Epoch [1/10], Batch [8110], Loss: 0.3628
# Epoch [1/10], Batch [8120], Loss: 0.3448
# Epoch [1/10], Batch [8130], Loss: 0.4093
# Epoch [1/10], Batch [8140], Loss: 0.3868
# Epoch [1/10], Batch [8150], Loss: 0.4230
# Epoch [1/10], Batch [8160], Loss: 659.9579
# Epoch [1/10], Batch [8170], Loss: 0.4011
# Epoch [1/10], Batch [8180], Loss: 0.3779
# Epoch [1/10], Batch [8190], Loss: 660.1695
# Epoch [1/10], Batch [8200], Loss: 0.2889
# Epoch [1/10], Batch [8210], Loss: 0.2346
# Epoch [1/10], Batch [8220], Loss: 0.1845
# Epoch [1/10], Batch [8230], Loss: 0.1648
# Epoch [1/10], Batch [8240], Loss: 0.1833
# Epoch [1/10], Batch [8250], Loss: 0.1581
# Epoch [1/10], Batch [8260], Loss: 661.8383
# Epoch [1/10], Batch [8270], Loss: 0.1764
# Epoch [1/10], Batch [8280], Loss: 0.1887
# Epoch [1/10], Batch [8290], Loss: 0.2132
# Epoch [1/10], Batch [8300], Loss: 0.2348
# Epoch [1/10], Batch [8310], Loss: 0.2802
# Epoch [1/10], Batch [8320], Loss: 0.3029
# Epoch [1/10], Batch [8330], Loss: 0.2643
# Epoch [1/10], Batch [8340], Loss: 0.2203
# Epoch [1/10], Batch [8350], Loss: 0.1755
# Epoch [1/10], Batch [8360], Loss: 0.1403
# Epoch [1/10], Batch [8370], Loss: 0.1341
# Epoch [1/10], Batch [8380], Loss: 0.1190
# Epoch [1/10], Batch [8390], Loss: 0.1243
# Epoch [1/10], Batch [8400], Loss: 0.1898
# Epoch [1/10], Batch [8410], Loss: 0.1964
# Epoch [1/10], Batch [8420], Loss: 0.1735
# Epoch [1/10], Batch [8430], Loss: 0.1430
# Epoch [1/10], Batch [8440], Loss: 0.1349
# Epoch [1/10], Batch [8450], Loss: 0.1405
# Epoch [1/10], Batch [8460], Loss: 0.1333
# Epoch [1/10], Batch [8470], Loss: 0.1190
# Epoch [1/10], Batch [8480], Loss: 0.1203
# Epoch [1/10], Batch [8490], Loss: 0.1312
# Epoch [1/10], Batch [8500], Loss: 0.1171
# Epoch [1/10], Batch [8510], Loss: 0.1146
# Epoch [1/10], Batch [8520], Loss: 0.1298
# Epoch [1/10], Batch [8530], Loss: 0.1219
# Epoch [1/10], Batch [8540], Loss: 0.1011
# Epoch [1/10], Batch [8550], Loss: 0.0803
# Epoch [1/10], Batch [8560], Loss: 0.0857
# Epoch [1/10], Batch [8570], Loss: 0.0991
# Epoch [1/10], Batch [8580], Loss: 0.1641
# Epoch [1/10], Batch [8590], Loss: 659.8494
# Epoch [1/10], Batch [8600], Loss: 0.3380
# Epoch [1/10], Batch [8610], Loss: 659.1124
# Epoch [1/10], Batch [8620], Loss: 0.3812
# Epoch [1/10], Batch [8630], Loss: 0.4161
# Epoch [1/10], Batch [8640], Loss: 0.3276
# Epoch [1/10], Batch [8650], Loss: 0.3030
# Epoch [1/10], Batch [8660], Loss: 0.2761
# Epoch [1/10], Batch [8670], Loss: 0.2441
# Epoch [1/10], Batch [8680], Loss: 0.2672
# Epoch [1/10], Batch [8690], Loss: 0.2486
# Epoch [1/10], Batch [8700], Loss: 0.2453
# Epoch [1/10], Batch [8710], Loss: 0.1852
# Epoch [1/10], Batch [8720], Loss: 0.1265
# Epoch [1/10], Batch [8730], Loss: 0.0773
# Epoch [1/10], Batch [8740], Loss: 0.1155
# Epoch [1/10], Batch [8750], Loss: 0.2054
# Epoch [1/10], Batch [8760], Loss: 0.2966
# Epoch [1/10], Batch [8770], Loss: 0.3125
# Epoch [1/10], Batch [8780], Loss: 0.3705
# Epoch [1/10], Batch [8790], Loss: 0.3286
# Epoch [1/10], Batch [8800], Loss: 0.2322
# Epoch [1/10], Batch [8810], Loss: 0.2274
# Epoch [1/10], Batch [8820], Loss: 0.1997
# Epoch [1/10], Batch [8830], Loss: 659.4222
# Epoch [1/10], Batch [8840], Loss: 0.2256
# Epoch [1/10], Batch [8850], Loss: 0.2146
# Epoch [1/10], Batch [8860], Loss: 0.2078
# Epoch [1/10], Batch [8870], Loss: 0.1860
# Epoch [1/10], Batch [8880], Loss: 0.2006
# Epoch [1/10], Batch [8890], Loss: 0.1781
# Epoch [1/10], Batch [8900], Loss: 659.8546
# Epoch [1/10], Batch [8910], Loss: 0.2323
# Epoch [1/10], Batch [8920], Loss: 0.2090
# Epoch [1/10], Batch [8930], Loss: 0.2308
# Epoch [1/10], Batch [8940], Loss: 0.2642
# Epoch [1/10], Batch [8950], Loss: 0.2739
# Epoch [1/10], Batch [8960], Loss: 0.2488
# Epoch [1/10], Batch [8970], Loss: 0.2494
# Epoch [1/10], Batch [8980], Loss: 0.2426
# Epoch [1/10], Batch [8990], Loss: 0.2418
# Epoch [1/10], Batch [9000], Loss: 0.2852
# Epoch [1/10], Batch [9010], Loss: 0.2746
# Epoch [1/10], Batch [9020], Loss: 0.2412
# Epoch [1/10], Batch [9030], Loss: 0.1968
# Epoch [1/10], Batch [9040], Loss: 0.2006
# Epoch [1/10], Batch [9050], Loss: 0.2247
# Epoch [1/10], Batch [9060], Loss: 658.1326
# Epoch [1/10], Batch [9070], Loss: 0.2358
# Epoch [1/10], Batch [9080], Loss: 0.2908
# Epoch [1/10], Batch [9090], Loss: 0.2206
# Epoch [1/10], Batch [9100], Loss: 0.2232
# Epoch [1/10], Batch [9110], Loss: 0.2431
# Epoch [1/10], Batch [9120], Loss: 0.3238
# Epoch [1/10], Batch [9130], Loss: 0.2720
# Epoch [1/10], Batch [9140], Loss: 0.2532
# Epoch [1/10], Batch [9150], Loss: 0.2974
# Epoch [1/10], Batch [9160], Loss: 0.3253
# Epoch [1/10], Batch [9170], Loss: 0.3861
# Epoch [1/10], Batch [9180], Loss: 0.3515
# Epoch [1/10], Batch [9190], Loss: 0.3401
# Epoch [1/10], Batch [9200], Loss: 0.2677
# Epoch [1/10], Batch [9210], Loss: 0.2885
# Epoch [1/10], Batch [9220], Loss: 657.2266
# Epoch [1/10], Batch [9230], Loss: 0.3805
# Epoch [1/10], Batch [9240], Loss: 0.3241
# Epoch [1/10], Batch [9250], Loss: 0.3067
# Epoch [1/10], Batch [9260], Loss: 0.2821
# Epoch [1/10], Batch [9270], Loss: 0.2641
# Epoch [1/10], Batch [9280], Loss: 0.2177
# Epoch [1/10], Batch [9290], Loss: 0.1562
# Epoch [1/10], Batch [9300], Loss: 0.1563
# Epoch [1/10], Batch [9310], Loss: 0.1258
# Epoch [1/10], Batch [9320], Loss: 0.1099
# Epoch [1/10], Batch [9330], Loss: 0.1224
# Epoch [1/10], Batch [9340], Loss: 0.1303
# Epoch [1/10], Batch [9350], Loss: 0.1269
# Epoch [1/10], Batch [9360], Loss: 0.1177
# Epoch [1/10], Batch [9370], Loss: 0.1557
# Epoch [1/10], Batch [9380], Loss: 0.1925
# Epoch [1/10], Batch [9390], Loss: 0.1870
# Epoch [1/10], Batch [9400], Loss: 0.1576
# Epoch [1/10], Batch [9410], Loss: 0.1232
# Epoch [1/10], Batch [9420], Loss: 0.1237
# Epoch [1/10], Batch [9430], Loss: 0.1345
# Epoch [1/10], Batch [9440], Loss: 0.1499
# Epoch [1/10], Batch [9450], Loss: 0.1485
# Epoch [1/10], Batch [9460], Loss: 0.1308
# Epoch [1/10], Batch [9470], Loss: 658.8503
# Epoch [1/10], Batch [9480], Loss: 0.1588
# Epoch [1/10], Batch [9490], Loss: 0.1628
# Epoch [1/10], Batch [9500], Loss: 0.1709
# Epoch [1/10], Batch [9510], Loss: 0.1687
# Epoch [1/10], Batch [9520], Loss: 657.7245
# Epoch [1/10], Batch [9530], Loss: 0.3308
# Epoch [1/10], Batch [9540], Loss: 0.3406
# Epoch [1/10], Batch [9550], Loss: 0.2738
# Epoch [1/10], Batch [9560], Loss: 0.2473
# Epoch [1/10], Batch [9570], Loss: 0.2833
# Epoch [1/10], Batch [9580], Loss: 0.2761
# Epoch [1/10], Batch [9590], Loss: 0.2719
# Epoch [1/10], Batch [9600], Loss: 0.2417
# Epoch [1/10], Batch [9610], Loss: 0.2292
# Epoch [1/10], Batch [9620], Loss: 0.1924
# Epoch [1/10], Batch [9630], Loss: 0.1660
# Epoch [1/10], Batch [9640], Loss: 657.2616
# Epoch [1/10], Batch [9650], Loss: 0.2255
# Epoch [1/10], Batch [9660], Loss: 0.2578
# Epoch [1/10], Batch [9670], Loss: 0.2869
# Epoch [1/10], Batch [9680], Loss: 0.2792
# Epoch [1/10], Batch [9690], Loss: 0.2529
# Epoch [1/10], Batch [9700], Loss: 0.2128
# Epoch [1/10], Batch [9710], Loss: 0.2015
# Epoch [1/10], Batch [9720], Loss: 0.1736
# Epoch [1/10], Batch [9730], Loss: 0.1478
# Epoch [1/10], Batch [9740], Loss: 0.1496
# Epoch [1/10], Batch [9750], Loss: 0.1570
# Epoch [1/10], Batch [9760], Loss: 0.1566
# Epoch [1/10], Batch [9770], Loss: 0.1646
# Epoch [1/10], Batch [9780], Loss: 655.9691
# Epoch [1/10], Batch [9790], Loss: 0.2595
# Epoch [1/10], Batch [9800], Loss: 0.2485
# Epoch [1/10], Batch [9810], Loss: 0.2516
# Epoch [1/10], Batch [9820], Loss: 0.2315
# Epoch [1/10], Batch [9830], Loss: 0.2005
# Epoch [1/10], Batch [9840], Loss: 0.2366
# Epoch [1/10], Batch [9850], Loss: 0.2469
# Epoch [1/10], Batch [9860], Loss: 0.1932
# Epoch [1/10], Batch [9870], Loss: 0.2011
# Epoch [1/10], Batch [9880], Loss: 0.1947
# Epoch [1/10], Batch [9890], Loss: 0.1371
# Epoch [1/10], Batch [9900], Loss: 0.1443
# Epoch [1/10], Batch [9910], Loss: 0.1180
# Epoch [1/10], Batch [9920], Loss: 0.1263
# Epoch [1/10], Batch [9930], Loss: 0.1280
# Epoch [1/10], Batch [9940], Loss: 656.8894
# Epoch [1/10], Batch [9950], Loss: 0.1434
# Epoch [1/10], Batch [9960], Loss: 0.1135
# Epoch [1/10], Batch [9970], Loss: 0.1847
# Epoch [1/10], Batch [9980], Loss: 0.2672
# Epoch [1/10], Batch [9990], Loss: 0.2972
# Epoch [1/10], Batch [10000], Loss: 0.4314
# Epoch [1/10], Batch [10010], Loss: 0.8136
# Epoch [1/10], Batch [10020], Loss: 0.7817
# Epoch [1/10], Batch [10030], Loss: 0.6058
# Epoch [1/10], Batch [10040], Loss: 0.5161
# Epoch [1/10], Batch [10050], Loss: 0.4588
# Epoch [1/10], Batch [10060], Loss: 0.5456
# Epoch [1/10], Batch [10070], Loss: 0.5533
# Epoch [1/10], Batch [10080], Loss: 0.6311
# Epoch [1/10], Batch [10090], Loss: 0.6048
# Epoch [1/10], Batch [10100], Loss: 0.4953
# Epoch [1/10], Batch [10110], Loss: 0.4078
# Epoch [1/10], Batch [10120], Loss: 0.3666
# Epoch [1/10], Batch [10130], Loss: 0.3346
# Epoch [1/10], Batch [10140], Loss: 0.2953
# Epoch [1/10], Batch [10150], Loss: 0.2648
# Epoch [1/10], Batch [10160], Loss: 0.3143
# Epoch [1/10], Batch [10170], Loss: 0.3302
# Epoch [1/10], Batch [10180], Loss: 0.3426
# Epoch [1/10], Batch [10190], Loss: 0.3800
# Epoch [1/10], Batch [10200], Loss: 0.3846
# Epoch [1/10], Batch [10210], Loss: 653.1754
# Epoch [1/10], Batch [10220], Loss: 0.3535
# Epoch [1/10], Batch [10230], Loss: 652.8232
# Epoch [1/10], Batch [10240], Loss: 0.4463
# Epoch [1/10], Batch [10250], Loss: 0.5504
# Epoch [1/10], Batch [10260], Loss: 651.8920
# Epoch [1/10], Batch [10270], Loss: 0.5314
# Epoch [1/10], Batch [10280], Loss: 0.5654
# Epoch [1/10], Batch [10290], Loss: 0.4624
# Epoch [1/10], Batch [10300], Loss: 0.3236
# Epoch [1/10], Batch [10310], Loss: 0.2662
# Epoch [1/10], Batch [10320], Loss: 0.2677
# Epoch [1/10], Batch [10330], Loss: 0.2508
# Epoch [1/10], Batch [10340], Loss: 0.2020
# Epoch [1/10], Batch [10350], Loss: 0.1938
# Epoch [1/10], Batch [10360], Loss: 0.1314
# Epoch [1/10], Batch [10370], Loss: 0.1212
# Epoch [1/10], Batch [10380], Loss: 0.0999
# Epoch [1/10], Batch [10390], Loss: 656.6568
# Epoch [1/10], Batch [10400], Loss: 0.0732
# Epoch [1/10], Batch [10410], Loss: 0.1216
# Epoch [1/10], Batch [10420], Loss: 0.1948
# Epoch [1/10], Batch [10430], Loss: 0.1963
# Epoch [1/10], Batch [10440], Loss: 0.1912
# Epoch [1/10], Batch [10450], Loss: 0.2189
# Epoch [1/10], Batch [10460], Loss: 0.1902
# Epoch [1/10], Batch [10470], Loss: 0.2056
# Epoch [1/10], Batch [10480], Loss: 0.2478
# Epoch [1/10], Batch [10490], Loss: 653.2302
# Epoch [1/10], Batch [10500], Loss: 0.3211
# Epoch [1/10], Batch [10510], Loss: 0.3826
# Epoch [1/10], Batch [10520], Loss: 0.3606
# Epoch [1/10], Batch [10530], Loss: 0.2930
# Epoch [1/10], Batch [10540], Loss: 0.2569
# Epoch [1/10], Batch [10550], Loss: 0.2430
# Epoch [1/10], Batch [10560], Loss: 0.2360
# Epoch [1/10], Batch [10570], Loss: 0.2303
# Epoch [1/10], Batch [10580], Loss: 0.2598
# Epoch [1/10], Batch [10590], Loss: 0.2692
# Epoch [1/10], Batch [10600], Loss: 0.3654
# Epoch [1/10], Batch [10610], Loss: 0.3664
# Epoch [1/10], Batch [10620], Loss: 651.4049
# Epoch [1/10], Batch [10630], Loss: 0.6659
# Epoch [1/10], Batch [10640], Loss: 0.6678
# Epoch [1/10], Batch [10650], Loss: 0.4672
# Epoch [1/10], Batch [10660], Loss: 0.4621
# Epoch [1/10], Batch [10670], Loss: 0.4753
# Epoch [1/10], Batch [10680], Loss: 0.5535
# Epoch [1/10], Batch [10690], Loss: 0.4463
# Epoch [1/10], Batch [10700], Loss: 651.2357
# Epoch [1/10], Batch [10710], Loss: 650.5834
# Epoch [1/10], Batch [10720], Loss: 0.4486
# Epoch [1/10], Batch [10730], Loss: 0.4165
# Epoch [1/10], Batch [10740], Loss: 0.3063
# Epoch [1/10], Batch [10750], Loss: 0.1983
# Epoch [1/10], Batch [10760], Loss: 0.2130
# Epoch [1/10], Batch [10770], Loss: 0.2380
# Epoch [1/10], Batch [10780], Loss: 0.2012
# Epoch [1/10], Batch [10790], Loss: 0.1756
# Epoch [1/10], Batch [10800], Loss: 0.1993
# Epoch [1/10], Batch [10810], Loss: 0.1634
# Epoch [1/10], Batch [10820], Loss: 0.1249
# Epoch [1/10], Batch [10830], Loss: 0.0806
# Epoch [1/10], Batch [10840], Loss: 0.1271
# Epoch [1/10], Batch [10850], Loss: 656.2188
# Epoch [1/10], Batch [10860], Loss: 0.1751
# Epoch [1/10], Batch [10870], Loss: 0.1685
# Epoch [1/10], Batch [10880], Loss: 0.2229
# Epoch [1/10], Batch [10890], Loss: 0.2072
# Epoch [1/10], Batch [10900], Loss: 0.2163
# Epoch [1/10], Batch [10910], Loss: 0.2306
# Epoch [1/10], Batch [10920], Loss: 0.1800
# Epoch [1/10], Batch [10930], Loss: 0.1958
# Epoch [1/10], Batch [10940], Loss: 0.2226
# Epoch [1/10], Batch [10950], Loss: 0.2326
# Epoch [1/10], Batch [10960], Loss: 652.9350
# Epoch [1/10], Batch [10970], Loss: 0.3904
# Epoch [1/10], Batch [10980], Loss: 0.3788
# Epoch [1/10], Batch [10990], Loss: 0.4161
# Epoch [1/10], Batch [11000], Loss: 0.4313
# Epoch [1/10], Batch [11010], Loss: 0.4485
# Epoch [1/10], Batch [11020], Loss: 0.5131
# Epoch [1/10], Batch [11030], Loss: 0.5470
# Epoch [1/10], Batch [11040], Loss: 0.4825
# Epoch [1/10], Batch [11050], Loss: 0.3856
# Epoch [1/10], Batch [11060], Loss: 0.3616
# Epoch [1/10], Batch [11070], Loss: 650.5470
# Epoch [1/10], Batch [11080], Loss: 0.4773
# Epoch [1/10], Batch [11090], Loss: 0.4843
# Epoch [1/10], Batch [11100], Loss: 0.5172
# Epoch [1/10], Batch [11110], Loss: 0.4498
# Epoch [1/10], Batch [11120], Loss: 0.3822
# Epoch [1/10], Batch [11130], Loss: 0.3475
# Epoch [1/10], Batch [11140], Loss: 0.3720
# Epoch [1/10], Batch [11150], Loss: 650.2083
# Epoch [1/10], Batch [11160], Loss: 0.4243
# Epoch [1/10], Batch [11170], Loss: 0.3705
# Epoch [1/10], Batch [11180], Loss: 0.3814
# Epoch [1/10], Batch [11190], Loss: 0.3602
# Epoch [1/10], Batch [11200], Loss: 0.3296
# Epoch [1/10], Batch [11210], Loss: 0.2899
# Epoch [1/10], Batch [11220], Loss: 0.2457
# Epoch [1/10], Batch [11230], Loss: 0.2180
# Epoch [1/10], Batch [11240], Loss: 650.8587
# Epoch [1/10], Batch [11250], Loss: 0.2642
# Epoch [1/10], Batch [11260], Loss: 0.3026
# Epoch [1/10], Batch [11270], Loss: 0.3406
# Epoch [1/10], Batch [11280], Loss: 0.5257
# Epoch [1/10], Batch [11290], Loss: 0.5201
# Epoch [1/10], Batch [11300], Loss: 0.5632
# Epoch [1/10], Batch [11310], Loss: 646.6146
# Epoch [1/10], Batch [11320], Loss: 1.0547
# Epoch [1/10], Batch [11330], Loss: 1.0697
# Epoch [1/10], Batch [11340], Loss: 0.8755
# Epoch [1/10], Batch [11350], Loss: 0.7322
# Epoch [1/10], Batch [11360], Loss: 0.6119
# Epoch [1/10], Batch [11370], Loss: 0.5924
# Epoch [1/10], Batch [11380], Loss: 0.6230
# Epoch [1/10], Batch [11390], Loss: 0.6558
# Epoch [1/10], Batch [11400], Loss: 0.5767
# Epoch [1/10], Batch [11410], Loss: 648.1257
# Epoch [1/10], Batch [11420], Loss: 0.4045
# Epoch [1/10], Batch [11430], Loss: 0.3297
# Epoch [1/10], Batch [11440], Loss: 0.2052
# Epoch [1/10], Batch [11450], Loss: 0.0869
# Epoch [1/10], Batch [11460], Loss: 0.1491
# Epoch [1/10], Batch [11470], Loss: 0.2529
# Epoch [1/10], Batch [11480], Loss: 0.2911
# Epoch [1/10], Batch [11490], Loss: 0.2528
# Epoch [1/10], Batch [11500], Loss: 0.2029
# Epoch [1/10], Batch [11510], Loss: 650.6320
# Epoch [1/10], Batch [11520], Loss: 0.1698
# Epoch [1/10], Batch [11530], Loss: 0.2347
# Epoch [1/10], Batch [11540], Loss: 0.3051
# Epoch [1/10], Batch [11550], Loss: 649.0431
# Epoch [1/10], Batch [11560], Loss: 648.5881
# Epoch [1/10], Batch [11570], Loss: 0.4313
# Epoch [1/10], Batch [11580], Loss: 0.4279
# Epoch [1/10], Batch [11590], Loss: 0.4263
# Epoch [1/10], Batch [11600], Loss: 0.3785
# Epoch [1/10], Batch [11610], Loss: 0.3873
# Epoch [1/10], Batch [11620], Loss: 649.4888
# Epoch [1/10], Batch [11630], Loss: 0.3341
# ...
# Epoch [10/10], Batch [10120], Loss: 0.1149
# Epoch [10/10], Batch [10130], Loss: 0.1196
# Epoch [10/10], Batch [10140], Loss: 0.1157
# Epoch [10/10], Batch [10150], Loss: 0.1029
# Epoch [10/10], Batch [10160], Loss: 321.1815
# Epoch [10/10], Batch [10170], Loss: 0.0871
# Epoch [10/10], Batch [10180], Loss: 0.0826
# Epoch [10/10], Batch [10190], Loss: 0.0851
# Epoch [10/10], Batch [10200], Loss: 0.0955
# Epoch [10/10], Batch [10210], Loss: 0.0990
# Epoch [10/10], Batch [10220], Loss: 320.8482
# Epoch [10/10], Batch [10230], Loss: 0.1285
# Epoch [10/10], Batch [10240], Loss: 0.1682
# Epoch [10/10], Batch [10250], Loss: 0.1899
# Epoch [10/10], Batch [10260], Loss: 0.1962
# Epoch [10/10], Batch [10270], Loss: 0.1846
# Epoch [10/10], Batch [10280], Loss: 0.1669
# Epoch [10/10], Batch [10290], Loss: 0.1496
# Epoch [10/10], Batch [10300], Loss: 0.1417
# Epoch [10/10], Batch [10310], Loss: 0.1432
# Epoch [10/10], Batch [10320], Loss: 320.2082
# Epoch [10/10], Batch [10330], Loss: 0.1497
# Epoch [10/10], Batch [10340], Loss: 0.1465
# Epoch [10/10], Batch [10350], Loss: 0.1475
# Epoch [10/10], Batch [10360], Loss: 0.1371
# Epoch [10/10], Batch [10370], Loss: 0.1430
# Epoch [10/10], Batch [10380], Loss: 0.1429
# Epoch [10/10], Batch [10390], Loss: 0.1377
# Epoch [10/10], Batch [10400], Loss: 0.1294
# Epoch [10/10], Batch [10410], Loss: 0.1234
# Epoch [10/10], Batch [10420], Loss: 0.1114
# Epoch [10/10], Batch [10430], Loss: 0.1014
# Epoch [10/10], Batch [10440], Loss: 0.1088
# Epoch [10/10], Batch [10450], Loss: 0.1198
# Epoch [10/10], Batch [10460], Loss: 0.1231
# Epoch [10/10], Batch [10470], Loss: 0.1305
# Epoch [10/10], Batch [10480], Loss: 0.1334
# Epoch [10/10], Batch [10490], Loss: 0.1526
# Epoch [10/10], Batch [10500], Loss: 0.1698
# Epoch [10/10], Batch [10510], Loss: 0.1709
# Epoch [10/10], Batch [10520], Loss: 0.1587
# Epoch [10/10], Batch [10530], Loss: 0.1407
# Epoch [10/10], Batch [10540], Loss: 0.1424
# Epoch [10/10], Batch [10550], Loss: 0.1389
# Epoch [10/10], Batch [10560], Loss: 0.1261
# Epoch [10/10], Batch [10570], Loss: 0.1220
# Epoch [10/10], Batch [10580], Loss: 0.1434
# Epoch [10/10], Batch [10590], Loss: 0.1544
# Epoch [10/10], Batch [10600], Loss: 0.1504
# Epoch [10/10], Batch [10610], Loss: 0.1484
# Epoch [10/10], Batch [10620], Loss: 319.2636
# Epoch [10/10], Batch [10630], Loss: 0.1603
# Epoch [10/10], Batch [10640], Loss: 0.1598
# Epoch [10/10], Batch [10650], Loss: 0.1578
# Epoch [10/10], Batch [10660], Loss: 0.1490
# Epoch [10/10], Batch [10670], Loss: 0.1360
# Epoch [10/10], Batch [10680], Loss: 0.1281
# Epoch [10/10], Batch [10690], Loss: 319.4782
# Epoch [10/10], Batch [10700], Loss: 319.3215
# Epoch [10/10], Batch [10710], Loss: 0.1332
# Epoch [10/10], Batch [10720], Loss: 0.1242
# Epoch [10/10], Batch [10730], Loss: 319.4291
# Epoch [10/10], Batch [10740], Loss: 319.3381
# Epoch [10/10], Batch [10750], Loss: 0.1225
# Epoch [10/10], Batch [10760], Loss: 0.1353
# Epoch [10/10], Batch [10770], Loss: 0.1325
# Epoch [10/10], Batch [10780], Loss: 0.1256
# Epoch [10/10], Batch [10790], Loss: 0.1197
# Epoch [10/10], Batch [10800], Loss: 0.1175
# Epoch [10/10], Batch [10810], Loss: 0.1223
# Epoch [10/10], Batch [10820], Loss: 0.1206
# Epoch [10/10], Batch [10830], Loss: 0.1216
# Epoch [10/10], Batch [10840], Loss: 0.1201
# Epoch [10/10], Batch [10850], Loss: 0.1213
# Epoch [10/10], Batch [10860], Loss: 0.1258
# Epoch [10/10], Batch [10870], Loss: 0.1289
# Epoch [10/10], Batch [10880], Loss: 0.1238
# Epoch [10/10], Batch [10890], Loss: 318.9547
# Epoch [10/10], Batch [10900], Loss: 0.1352
# Epoch [10/10], Batch [10910], Loss: 0.1500
# Epoch [10/10], Batch [10920], Loss: 0.1611
# Epoch [10/10], Batch [10930], Loss: 0.1713
# Epoch [10/10], Batch [10940], Loss: 0.1746
# Epoch [10/10], Batch [10950], Loss: 0.1660
# Epoch [10/10], Batch [10960], Loss: 318.3891
# Epoch [10/10], Batch [10970], Loss: 0.1555
# Epoch [10/10], Batch [10980], Loss: 0.1528
# Epoch [10/10], Batch [10990], Loss: 0.1478
# Epoch [10/10], Batch [11000], Loss: 0.1477
# Epoch [10/10], Batch [11010], Loss: 0.1639
# Epoch [10/10], Batch [11020], Loss: 0.1783
# Epoch [10/10], Batch [11030], Loss: 0.1871
# Epoch [10/10], Batch [11040], Loss: 0.1757
# Epoch [10/10], Batch [11050], Loss: 0.1616
# Epoch [10/10], Batch [11060], Loss: 0.1444
# Epoch [10/10], Batch [11070], Loss: 0.1333
# Epoch [10/10], Batch [11080], Loss: 0.1263
# Epoch [10/10], Batch [11090], Loss: 318.4158
# Epoch [10/10], Batch [11100], Loss: 0.1335
# Epoch [10/10], Batch [11110], Loss: 318.2090
# Epoch [10/10], Batch [11120], Loss: 0.1308
# Epoch [10/10], Batch [11130], Loss: 0.1250
# Epoch [10/10], Batch [11140], Loss: 0.1232
# Epoch [10/10], Batch [11150], Loss: 0.1115
# Epoch [10/10], Batch [11160], Loss: 0.1167
# Epoch [10/10], Batch [11170], Loss: 0.1182
# Epoch [10/10], Batch [11180], Loss: 318.2006
# Epoch [10/10], Batch [11190], Loss: 0.1355
# Epoch [10/10], Batch [11200], Loss: 0.1315
# Epoch [10/10], Batch [11210], Loss: 0.1295
# Epoch [10/10], Batch [11220], Loss: 0.1404
# Epoch [10/10], Batch [11230], Loss: 0.1596
# Epoch [10/10], Batch [11240], Loss: 0.1721
# Epoch [10/10], Batch [11250], Loss: 0.1651
# Epoch [10/10], Batch [11260], Loss: 0.1627
# Epoch [10/10], Batch [11270], Loss: 0.1690
# Epoch [10/10], Batch [11280], Loss: 0.1748
# Epoch [10/10], Batch [11290], Loss: 317.3331
# Epoch [10/10], Batch [11300], Loss: 0.1995
# Epoch [10/10], Batch [11310], Loss: 0.2053
# Epoch [10/10], Batch [11320], Loss: 0.2023
# Epoch [10/10], Batch [11330], Loss: 0.2102
# Epoch [10/10], Batch [11340], Loss: 0.2163
# Epoch [10/10], Batch [11350], Loss: 0.2053
# Epoch [10/10], Batch [11360], Loss: 0.1916
# Epoch [10/10], Batch [11370], Loss: 0.1819
# Epoch [10/10], Batch [11380], Loss: 0.1823
# Epoch [10/10], Batch [11390], Loss: 0.1973
# Epoch [10/10], Batch [11400], Loss: 0.1922
# Epoch [10/10], Batch [11410], Loss: 0.1864
# Epoch [10/10], Batch [11420], Loss: 0.1797
# Epoch [10/10], Batch [11430], Loss: 0.1718
# Epoch [10/10], Batch [11440], Loss: 0.1571
# Epoch [10/10], Batch [11450], Loss: 0.1421
# Epoch [10/10], Batch [11460], Loss: 0.1469
# Epoch [10/10], Batch [11470], Loss: 317.2176
# Epoch [10/10], Batch [11480], Loss: 0.1388
# Epoch [10/10], Batch [11490], Loss: 0.1331
# Epoch [10/10], Batch [11500], Loss: 0.1369
# Epoch [10/10], Batch [11510], Loss: 0.1294
# Epoch [10/10], Batch [11520], Loss: 0.1203
# Epoch [10/10], Batch [11530], Loss: 0.1028
# Epoch [10/10], Batch [11540], Loss: 0.1081
# Epoch [10/10], Batch [11550], Loss: 317.3443
# Epoch [10/10], Batch [11560], Loss: 0.1371
# Epoch [10/10], Batch [11570], Loss: 0.1413
# Epoch [10/10], Batch [11580], Loss: 0.1465
# Epoch [10/10], Batch [11590], Loss: 0.1634
# Epoch [10/10], Batch [11600], Loss: 0.1638
# Epoch [10/10], Batch [11610], Loss: 0.1485
# Epoch [10/10], Batch [11620], Loss: 0.1391
# Epoch [10/10], Batch [11630], Loss: 0.1320
# Epoch [10/10], Batch [11640], Loss: 0.1233
# Epoch [10/10], Batch [11650], Loss: 0.1190
# Epoch [10/10], Batch [11660], Loss: 0.1157
# Epoch [10/10], Batch [11670], Loss: 0.1088
# Epoch [10/10], Batch [11680], Loss: 0.1055
# Epoch [10/10], Batch [11690], Loss: 317.2770
# Epoch [10/10], Batch [11700], Loss: 0.1006
# Epoch [10/10], Batch [11710], Loss: 0.0906
# Epoch [10/10], Batch [11720], Loss: 0.0769
# Epoch [10/10], Batch [11730], Loss: 0.0642
# Epoch [10/10], Batch [11740], Loss: 0.0918
# Epoch [10/10], Batch [11750], Loss: 0.1102
# Epoch [10/10], Batch [11760], Loss: 0.1170
# Epoch [10/10], Batch [11770], Loss: 0.1256
# Epoch [10/10], Batch [11780], Loss: 0.1329
# Epoch [10/10], Batch [11790], Loss: 0.1402
# Epoch [10/10], Batch [11800], Loss: 0.1506
# Epoch [10/10], Batch [11810], Loss: 0.1441
# Epoch [10/10], Batch [11820], Loss: 0.1372
# Epoch [10/10], Batch [11830], Loss: 0.1389
# Epoch [10/10], Batch [11840], Loss: 0.1302
# Epoch [10/10], Batch [11850], Loss: 0.1201
# Epoch [10/10], Batch [11860], Loss: 0.1225
# Epoch [10/10], Batch [11870], Loss: 0.1168
# Epoch [10/10], Batch [11880], Loss: 0.1019
# Epoch [10/10], Batch [11890], Loss: 0.0815
# Epoch [10/10], Batch [11900], Loss: 0.0600
# Epoch [10/10], Batch [11910], Loss: 0.0340
# Epoch [10/10], Batch [11920], Loss: 0.0478
# Epoch [10/10], Batch [11930], Loss: 0.0587
# Epoch [10/10], Batch [11940], Loss: 0.0528
# Epoch [10/10], Batch [11950], Loss: 0.0838
# Epoch [10/10], Batch [11960], Loss: 0.0963
# Epoch [10/10], Batch [11970], Loss: 0.0927
# Epoch [10/10], Batch [11980], Loss: 0.0824
# Epoch [10/10], Batch [11990], Loss: 0.0915
# Epoch [10/10], Batch [12000], Loss: 0.1001
# Epoch [10/10], Batch [12010], Loss: 0.1087
# Epoch [10/10], Batch [12020], Loss: 0.1189
# Epoch [10/10], Batch [12030], Loss: 0.1189
# Epoch [10/10], Batch [12040], Loss: 0.1166
# Epoch [10/10], Batch [12050], Loss: 0.1242
# Epoch [10/10], Batch [12060], Loss: 0.1355
# Epoch [10/10], Batch [12070], Loss: 0.1430
# Epoch [10/10], Batch [12080], Loss: 0.1423
# Epoch [10/10], Batch [12090], Loss: 0.1439
# Epoch [10/10], Batch [12100], Loss: 0.1483
# Epoch [10/10], Batch [12110], Loss: 0.1402
# Epoch [10/10], Batch [12120], Loss: 0.1288
# Epoch [10/10], Batch [12130], Loss: 316.0160
# Epoch [10/10], Batch [12140], Loss: 0.1239
# Epoch [10/10], Batch [12150], Loss: 0.1183
# Epoch [10/10], Batch [12160], Loss: 0.1205
# Epoch [10/10], Batch [12170], Loss: 0.1258
# Epoch [10/10], Batch [12180], Loss: 0.1298
# Epoch [10/10], Batch [12190], Loss: 0.1419
# Epoch [10/10], Batch [12200], Loss: 0.1367
# Epoch [10/10], Batch [12210], Loss: 0.1354
# Epoch [10/10], Batch [12220], Loss: 315.8278
# Epoch [10/10], Batch [12230], Loss: 0.1364
# Epoch [10/10], Batch [12240], Loss: 0.1504
# Epoch [10/10], Batch [12250], Loss: 0.1710
# Epoch [10/10], Batch [12260], Loss: 0.1767
# Epoch [10/10], Batch [12270], Loss: 0.1699
# Epoch [10/10], Batch [12280], Loss: 0.1581
# Epoch [10/10], Batch [12290], Loss: 0.1500
# Epoch [10/10], Batch [12300], Loss: 0.1518
# Epoch [10/10], Batch [12310], Loss: 0.1568
# Epoch [10/10], Batch [12320], Loss: 0.1517
# Epoch [10/10], Batch [12330], Loss: 0.1426
# Epoch [10/10], Batch [12340], Loss: 0.1423
# Epoch [10/10], Batch [12350], Loss: 0.1497
# Epoch [10/10], Batch [12360], Loss: 0.1481
# Epoch [10/10], Batch [12370], Loss: 0.1458
# Epoch [10/10], Batch [12380], Loss: 0.1415
# Epoch [10/10], Batch [12390], Loss: 0.1392
# Epoch [10/10], Batch [12400], Loss: 0.1394
# Epoch [10/10], Batch [12410], Loss: 315.3202
# Epoch [10/10], Batch [12420], Loss: 0.1306
# Epoch [10/10], Batch [12430], Loss: 0.1340
# Epoch [10/10], Batch [12440], Loss: 0.1333
# Epoch [10/10], Batch [12450], Loss: 0.1388
# Epoch [10/10], Batch [12460], Loss: 0.1369
# Epoch [10/10], Batch [12470], Loss: 0.1350
# Epoch [10/10], Batch [12480], Loss: 0.1271
# Epoch [10/10], Batch [12490], Loss: 315.2750
# Epoch [10/10], Batch [12500], Loss: 0.1334
# Epoch [10/10], Batch [12510], Loss: 0.1438
# Epoch [10/10], Batch [12520], Loss: 0.1466
# Epoch [10/10], Batch [12530], Loss: 0.1433
# Epoch [10/10], Batch [12540], Loss: 0.1328
# Epoch [10/10], Batch [12550], Loss: 0.1204
# Epoch [10/10], Batch [12560], Loss: 0.1109
# Epoch [10/10], Batch [12570], Loss: 0.0983
# Epoch [10/10], Batch [12580], Loss: 0.0878
# Epoch [10/10], Batch [12590], Loss: 0.0913
# Epoch [10/10], Batch [12600], Loss: 0.1078
# Epoch [10/10], Batch [12610], Loss: 0.1132
# Epoch [10/10], Batch [12620], Loss: 0.1078
# Epoch [10/10], Batch [12630], Loss: 315.1498
# Epoch [10/10], Batch [12640], Loss: 0.1084
# Epoch [10/10], Batch [12650], Loss: 0.1086
# Epoch [10/10], Batch [12660], Loss: 0.1038
# Epoch [10/10], Batch [12670], Loss: 0.0964
# Epoch [10/10], Batch [12680], Loss: 315.1845
# Epoch [10/10], Batch [12690], Loss: 0.1098
# Epoch [10/10], Batch [12700], Loss: 0.1149
# Epoch [10/10], Batch [12710], Loss: 0.1212
# Epoch [10/10], Batch [12720], Loss: 0.1183
# Epoch [10/10], Batch [12730], Loss: 0.1118
# Epoch [10/10], Batch [12740], Loss: 0.1080
# Epoch [10/10], Batch [12750], Loss: 0.1055
# Epoch [10/10], Batch [12760], Loss: 0.1061
# Epoch [10/10], Batch [12770], Loss: 314.7249
# Epoch [10/10], Batch [12780], Loss: 314.5928
# Epoch [10/10], Batch [12790], Loss: 0.1261
# Epoch [10/10], Batch [12800], Loss: 0.1206
# Epoch [10/10], Batch [12810], Loss: 0.1112
# Epoch [10/10], Batch [12820], Loss: 0.1095
# Epoch [10/10], Batch [12830], Loss: 0.1083
# Epoch [10/10], Batch [12840], Loss: 0.1041
# Epoch [10/10], Batch [12850], Loss: 0.1104
# Epoch [10/10], Batch [12860], Loss: 0.1248
# Epoch [10/10], Batch [12870], Loss: 0.1379
# Epoch [10/10], Batch [12880], Loss: 0.1329
# Epoch [10/10], Batch [12890], Loss: 0.1282
# Epoch [10/10], Batch [12900], Loss: 0.1304
# Epoch [10/10], Batch [12910], Loss: 0.1318
# Epoch [10/10], Batch [12920], Loss: 0.1289
# Epoch [10/10], Batch [12930], Loss: 0.1259
# Epoch [10/10], Batch [12940], Loss: 0.1216
# Epoch [10/10], Batch [12950], Loss: 0.1224
# Epoch [10/10], Batch [12960], Loss: 0.1174
# Epoch [10/10], Batch [12970], Loss: 0.1089
# Epoch [10/10], Batch [12980], Loss: 0.1032
# Epoch [10/10], Batch [12990], Loss: 0.1007
# Epoch [10/10], Batch [13000], Loss: 0.0917
# Epoch [10/10], Batch [13010], Loss: 0.0866
# Epoch [10/10], Batch [13020], Loss: 0.0893
# Epoch [10/10], Batch [13030], Loss: 0.1008
# Epoch [10/10], Batch [13040], Loss: 0.1046
# Epoch [10/10], Batch [13050], Loss: 0.1078
# Epoch [10/10], Batch [13060], Loss: 0.1051
# Epoch [10/10], Batch [13070], Loss: 0.0971
# Epoch [10/10], Batch [13080], Loss: 0.0964
# Epoch [10/10], Batch [13090], Loss: 0.1011
# Epoch [10/10], Batch [13100], Loss: 0.1198
# Epoch [10/10], Batch [13110], Loss: 0.1243
# Epoch [10/10], Batch [13120], Loss: 0.1260
# Epoch [10/10], Batch [13130], Loss: 0.1280
# Epoch [10/10], Batch [13140], Loss: 0.1298
# Epoch [10/10], Batch [13150], Loss: 0.1338
# Epoch [10/10], Batch [13160], Loss: 0.1378
# Epoch [10/10], Batch [13170], Loss: 313.5136
# Epoch [10/10], Batch [13180], Loss: 0.1524
# Epoch [10/10], Batch [13190], Loss: 0.1426
# Epoch [10/10], Batch [13200], Loss: 0.1464
# Epoch [10/10], Batch [13210], Loss: 0.1471
# Epoch [10/10], Batch [13220], Loss: 0.1405
# Epoch [10/10], Batch [13230], Loss: 0.1285
# Epoch [10/10], Batch [13240], Loss: 0.1230
# Epoch [10/10], Batch [13250], Loss: 0.1143
# Epoch [10/10], Batch [13260], Loss: 0.1086
# Epoch [10/10], Batch [13270], Loss: 0.1041
# Epoch [10/10], Batch [13280], Loss: 0.1127
# Epoch [10/10], Batch [13290], Loss: 313.6468
# Epoch [10/10], Batch [13300], Loss: 0.1105
# Epoch [10/10], Batch [13310], Loss: 0.1036
# Epoch [10/10], Batch [13320], Loss: 0.1046
# Epoch [10/10], Batch [13330], Loss: 0.1049
# Epoch [10/10], Batch [13340], Loss: 0.1108
# Epoch [10/10], Batch [13350], Loss: 0.1152
# Epoch [10/10], Batch [13360], Loss: 0.1124
# Epoch [10/10], Batch [13370], Loss: 0.1092
# Epoch [10/10], Batch [13380], Loss: 0.1101
# Epoch [10/10], Batch [13390], Loss: 0.1194
# Epoch [10/10], Batch [13400], Loss: 0.1354
# Epoch [10/10], Batch [13410], Loss: 0.1361
# Epoch [10/10], Batch [13420], Loss: 0.1550
# Epoch [10/10], Batch [13430], Loss: 0.1624
# Epoch [10/10], Batch [13440], Loss: 312.7689
# Epoch [10/10], Batch [13450], Loss: 0.1639
# Epoch [10/10], Batch [13460], Loss: 0.1537
# Epoch [10/10], Batch [13470], Loss: 0.1401
# Epoch [10/10], Batch [13480], Loss: 0.1355
# Epoch [10/10], Batch [13490], Loss: 0.1292
# Epoch [10/10], Batch [13500], Loss: 0.1334
# Epoch [10/10], Batch [13510], Loss: 0.1366
# Epoch [10/10], Batch [13520], Loss: 0.1363
# Epoch [10/10], Batch [13530], Loss: 0.1367
# Epoch [10/10], Batch [13540], Loss: 0.1284
# Epoch [10/10], Batch [13550], Loss: 0.1267
# Epoch [10/10], Batch [13560], Loss: 0.1444
# Epoch [10/10], Batch [13570], Loss: 0.1677
# Epoch [10/10], Batch [13580], Loss: 0.1788
# Epoch [10/10], Batch [13590], Loss: 0.1736
# Epoch [10/10], Batch [13600], Loss: 0.1591
# Epoch [10/10], Batch [13610], Loss: 312.3394
# Epoch [10/10], Batch [13620], Loss: 0.1730
# Epoch [10/10], Batch [13630], Loss: 0.1926
# Epoch [10/10], Batch [13640], Loss: 0.1860
# Epoch [10/10], Batch [13650], Loss: 0.1805
# Epoch [10/10], Batch [13660], Loss: 0.1667
# Epoch [10/10], Batch [13670], Loss: 0.1491
# Epoch [10/10], Batch [13680], Loss: 0.1353
# Epoch [10/10], Batch [13690], Loss: 0.1253
# Epoch [10/10], Batch [13700], Loss: 0.1186
# Epoch [10/10], Batch [13710], Loss: 0.1203
# Epoch [10/10], Batch [13720], Loss: 0.1259
# Epoch [10/10], Batch [13730], Loss: 0.1318
# Epoch [10/10], Batch [13740], Loss: 0.1227
# Epoch [10/10], Batch [13750], Loss: 0.1198
# Epoch [10/10], Batch [13760], Loss: 0.1176
# Epoch [10/10], Batch [13770], Loss: 0.1364
# Epoch [10/10], Batch [13780], Loss: 0.1460
# Epoch [10/10], Batch [13790], Loss: 0.1458
# Epoch [10/10], Batch [13800], Loss: 0.1375
# Epoch [10/10], Batch [13810], Loss: 0.1238

# %%
# Save the model after training
torch.save(model.state_dict(), 'lstm_model.pth')

# %%
# Load validation data in batches
valid_loader = du.DataLoader(dataset=valid_dataset, 
                             batch_size=batch_size, 
                             shuffle=True)

# %%
# Evaluation loop
model.eval()
valid_loss = 0.0
total_samples = 0
total_weighted_correct = 0.0

with torch.no_grad():
    for data, target, weight, additional_feature in valid_loader:
        data, target, weight, additional_feature = data.to(device), target.to(device), weight.to(device), additional_feature.to(device)
        
        output = model(data, additional_feature)
        
        # Compute the weighted MSE loss manually
        mse_loss = (weight * (output - target) ** 2).mean()
        test_loss += mse_loss.item() * data.size(0)
        
        # Compute weighted prediction accuracy (assuming binary classification)
        predicted = (output > 0).float()
        correct = (predicted == target).float() * weight
        total_weighted_correct += correct.sum().item()
        total_samples += weight.sum().item()
    
    # Calculate average loss and accuracy
    valid_loss /= total_samples
    valid_weighted_accuracy = total_weighted_correct / total_samples

    print(f"Validation Weighted MSE Loss: {valid_loss:.4f}")
    print(f"Validation Weighted Accuracy: {valid_weighted_accuracy:.4f}")
# Out:
# Validation Weighted MSE Loss: 0.0000
# Validation Weighted Accuracy: 0.5000

# %%
# Load test data in batches
test_loader = du.DataLoader(dataset=test_dataset, 
                             batch_size=batch_size, 
                             shuffle=False)

# %%
# Load test data in batches
test_loader = du.DataLoader(dataset=test_dataset, 
                            batch_size=batch_size, 
                            shuffle=False)

# Set model to evaluation mode
model.eval()

# Disable gradient calculation
with torch.no_grad():
    test_loss = 0.0
    test_correct = 0
    test_total_weight = 0.0

    for data, target, weight, accessibility in test_loader:  # Unpacking four values
        data, target, weight, accessibility = data.to(device), target.to(device), weight.to(device), accessibility.to(device)
        
        # Forward pass
        output = model(data, accessibility)
        
        # Calculate loss
        loss = criterion(output, target)
        test_loss += loss.item()
        
        # Compute weighted prediction accuracy
        predicted = (output > 0).float()
        test_correct += (predicted == target).sum().item()
        test_total_weight += weight.sum().item()  # Use weight.sum() as before for total weight
        
    # Calculate and print the average loss and accuracy
    test_loss /= len(test_loader.dataset)
    test_accuracy = test_correct / test_total_weight
    print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Test Loss: 0.0508, Test Accuracy: 0.0042
